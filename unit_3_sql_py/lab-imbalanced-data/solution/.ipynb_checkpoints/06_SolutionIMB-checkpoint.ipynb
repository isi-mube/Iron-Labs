# %% [markdown]
# ## 00 | In a nutshell;

# %% [markdown]
# <blockquote style="background-color: #d4edda; color: #155724; border-color: #c3e6cb; padding: 10px; border-radius: 5px;">
#
# * Of all techniques used to deal with imbalanced data, `SMOTE` showed the best results.
# * Why? For this case, `SMOTE` is able to generate synthetic data for the `minority` class (`No`) without doing any change to the `majority` class (`Yes`) getting the most balanced results compared to the previous:
# </blockquote>

# %% [markdown]
# ![image.png](attachment:088a0e8b-4418-4ec6-a279-77a30cf277ba.png)

# %% [markdown]
# ![image.png](attachment:e292fbd1-c4b8-496e-b12a-419adba7c587.png)

# %% [markdown]
# ![image.png](attachment:88f91e2c-3583-4240-873a-e7466202051f.png)

# %% [markdown]
# ![image.png](attachment:3ca30f32-6f9e-4953-a695-9f987d00a720.png)

# %% [markdown]
# ![image.png](attachment:b7c27270-a97e-43aa-af94-2ce030fc19c0.png)

# %% [markdown]
# ![image.png](attachment:263918bc-7b82-4159-85c7-edb60769e782.png)

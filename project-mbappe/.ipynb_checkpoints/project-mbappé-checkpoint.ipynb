# %% [markdown]
# ## 00. Coding Best Practices

# %%
# Basic Libraries
import os
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Machine Learning
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Settings
warnings.filterwarnings('ignore') 
pd.set_option('display.max_columns', None)

# %%
# Basic functions
def data_info(): # improved data.info()
    print(f"The DataFrame shape is {data.shape}.")
    print()
    print("The DataFrame data types are:")
    print(data.dtypes.value_counts().tolist())
    print(data.dtypes.value_counts().index.tolist())
    print()
    print("DataFrame random row sample and full columns:")
    return data.sample(5)

def clean_columns(): # Standardizes the column name, returns the columns
    data_copy.columns = [i.lower().replace(' ', '_') for i in data_copy.columns]
    return data_copy.sample(0)
       
# Specific functions for this dataset
def convert_value(value): # function to convert value to unified format
    try:
        if isinstance(value, float):
            return value
        elif value.endswith('K'):
            return float(value[1:-1]) * 1000
        elif value.endswith('M'):
            return float(value[1:-1]) * 1000000
        else:
            return float(value)
    except ValueError:
        return None

# Useful functions to keep, not used in this project:

def remove_outliers(data, column_name, whis): # self-explanatory 
    Q1 = data[column_name].quantile(0.25)
    Q3 = data[column_name].quantile(0.75)
    IQR = Q3 - Q1
    return data[~((data[column_name] < (Q1 - whis * IQR)) | (data[column_name] > (Q3 + whis * IQR))).any(axis=1)]

def check_null(data_copy): # Checks for empty cells in the entire DataFrame
    null_cols = data_copy.isnull().sum() # Checks for empty cells in the entire DataFrame
    null_cols = null_cols[null_cols > 0]
    print(null_cols)
    
def check_nan(data_copy): # Checks for NaN values in the entire DataFrame
    nan_cols = data_copy.isna().sum()
    nan_cols = nan_cols[nan_cols > 0]
    print(nan_cols)
    
def is_significant(column_name, data_copy): # takes a column name
    n_data = len(data_copy)
    n_nulls = data_copy[column_name].isnull().sum() # counts all NaNs of column name
    null_percentage = n_nulls / n_data * 100
    print(f"{null_percentage:.2f}% of the '{column_name}' column are empty.")

# %% [markdown]
# ## 01 - Getting the Data

# %%
file_path = os.path.join("C:/Users/apisi/01. IronData/01. GitHub/01. iron-activity/project-mbappe", "fifa21_male2.csv")
data = pd.read_csv(file_path)
data_info()
# Out:
# The DataFrame shape is (17125, 107).
#
# The DataFrame data types are:
# [52, 45, 10]
# [dtype('O'), dtype('int64'), dtype('float64')]
#
# DataFrame random row sample and full columns:
#            ID        Name  Age  OVA   Nationality              Club  BOV   BP  \
# 16952  258667  E. Bristow   18   56       England           Reading   57  LWB
# 11616  240164     D. Zuma   25   69  South Africa     Kaizer Chiefs   70  CAM
# 2470   189709      Alcalá   31   70         Spain         Girona FC   70   CB
# 369    122428  N. Belhadj   27   75       Algeria        Portsmouth   77   CF
# 10554  236518   A. Nordin   22   72        France  AS Saint-Étienne   73   LM
#
#         Position                                       Player Photo  \
# 16952      LB CB  https://cdn.sofifa.com/players/258/667/20_120.png
# 11616  RM LM CAM  https://cdn.sofifa.com/players/240/164/20_120.png
# 2470          CB  https://cdn.sofifa.com/players/189/709/20_120.png
# 369          NaN  https://cdn.sofifa.com/players/122/428/10_120.png
# 10554      LM RM  https://cdn.sofifa.com/players/236/518/20_120.png
#
#                                               Club Logo  \
# 16952    https://cdn.sofifa.com/teams/1793/light_60.png
# 11616  https://cdn.sofifa.com/teams/110929/light_60.png
# 2470   https://cdn.sofifa.com/teams/110062/light_60.png
# 369      https://cdn.sofifa.com/teams/1790/light_60.png
# 10554    https://cdn.sofifa.com/teams/1819/light_60.png
#
#                                     Flag Photo  POT  \
# 16952  https://cdn.sofifa.com/flags/gb-eng.png   71
# 11616      https://cdn.sofifa.com/flags/za.png   72
# 2470       https://cdn.sofifa.com/flags/es.png   70
# 369        https://cdn.sofifa.com/flags/dz.png   82
# 10554      https://cdn.sofifa.com/flags/fr.png   80
#
#                     Team & Contract Height  Weight   foot  Growth  \
# 16952           Reading 2020 ~ 2021  5'10"  150lbs   Left      15
# 11616     Kaizer Chiefs 2017 ~ 2023   5'7"  159lbs  Right       3
# 2470          Girona FC 2015 ~ 2021   6'5"  205lbs  Right       0
# 369                 Portsmouth 2013   5'9"  148lbs   Left       7
# 10554  AS Saint-Étienne 2016 ~ 2022   5'7"  152lbs   Left       8
#
#              Joined Loan Date End  Value  Wage Release Clause     Contract  \
# 16952   Jul 1, 2020           NaN  €170K  €650          €429K  2020 ~ 2021
# 11616  Jul 27, 2017           NaN  €1.3M  €500            €3M  2017 ~ 2023
# 2470   Aug 30, 2015           NaN  €1.3M   €6K          €2.1M  2015 ~ 2021
# 369             NaN           NaN     €0    €0             €0         2013
# 10554  Nov 22, 2016           NaN  €4.6M  €19K         €10.1M  2016 ~ 2022
#
#        Attacking  Crossing  Finishing  Heading Accuracy  Short Passing  \
# 16952        206        56         31                48             48
# 11616        289        67         60                38             69
# 2470         248        45         30                70             66
# 369          255        76         32                74             73
# 10554        323        65         69                67             70
#
#        Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing  \
# 16952     23.0    236         54   55.0           32            42
# 11616     55.0    315         74   61.0           50            60
# 2470      37.0    306         50   62.0           65            66
# 369        NaN    285         73    NaN           61            76
# 10554     52.0    322         74   65.0           44            65
#
#        Ball Control  Movement  Acceleration  Sprint Speed  Agility  Reactions  \
# 16952            53       335            77            78     63.0         49
# 11616            70       366            78            74     72.0         64
# 2470             63       201            31            37     31.0         70
# 369              75       249            89            91      NaN         69
# 10554            74       376            81            80     71.0         66
#
#        Balance  Power  Shot Power  Jumping  Stamina  Strength  Long Shots  \
# 16952     68.0    253          24     67.0       65        68          29
# 11616     78.0    252          50     41.0       61        45          55
# 2470      32.0    352          80     60.0       53        91          68
# 369        NaN    271          63      NaN       74        71          63
# 10554     78.0    327          72     63.0       63        64          65
#
#        Mentality  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 16952        242          63           47.0         49.0    44.0         39
# 11616        252          38           35.0         66.0    65.0         48
# 2470         254          72           69.0         26.0    48.0         39
# 369          268          73           59.0         65.0     NaN         71
# 10554        257          31           33.0         70.0    68.0         55
#
#        Composure  Defending  Marking  Standing Tackle  Sliding Tackle  \
# 16952       46.0        149       49               52            48.0
# 11616       62.0        123       55               35            33.0
# 2470        69.0        205       70               70            65.0
# 369          NaN        149       74               75             NaN
# 10554       58.0         94       36               32            26.0
#
#        Goalkeeping  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 16952           45          8            7          11               6
# 11616           39         11            7           7               7
# 2470            52         15           10           8               8
# 369             76          7           23          76              23
# 10554           56         14            6          13              10
#
#        GK Reflexes  Total Stats  Base Stats  W/F  SM     A/W     D/W   IR  \
# 16952           13         1466         325  3 ★  2★    High    High  1 ★
# 11616            7         1636         357  4 ★  3★  Medium  Medium  1 ★
# 2470            11         1618         337  4 ★  2★  Medium  Medium  1 ★
# 369             23         1553         429  3 ★  1★     NaN     NaN  2 ★
# 10554           13         1755         380  4 ★  3★  Medium  Medium  1 ★
#
#        PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST    RS    LW    LF    CF  \
# 16952   78   30   47   55   49   66    3  46+2  46+2  46+2  52+0  49+0  49+0
# 11616   76   56   65   72   41   47    5  61+2  61+2  61+2  68+0  66+0  66+0
# 2470    34   48   58   52   69   76   13  53+2  53+2  53+2  48+0  51+0  51+0
# 369     90   50   73   73   71   72    3  62+0  62+0  62+0  77+0  62+0  62+0
# 10554   80   67   66   74   36   57   37  70+2  70+2  70+2  71+0  71+0  71+0
#
#          RF    RW   LAM   CAM   RAM    LM   LCM    CM   RCM    RM   LWB   LDM  \
# 16952  49+0  52+0  49+2  49+2  49+2  54+2  48+2  48+2  48+2  54+2  55+2  51+2
# 11616  66+0  68+0  68+2  68+2  68+2  68+2  63+2  63+2  63+2  68+2  57+2  53+2
# 2470   51+0  48+0  52+2  52+2  52+2  50+2  59+2  59+2  59+2  50+2  59+2  67+2
# 369    62+0  77+0  70+0  70+0  70+0  77+0  74+0  74+0  74+0  77+0  77+0  74+0
# 10554  71+0  71+0  71+2  71+2  71+2  71+2  65+2  65+2  65+2  71+2  55+2  52+2
#
#         CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK Gender
# 16952  51+2  51+2  55+2  54+2  53+2  53+2  53+2  54+2  13+2   Male
# 11616  53+2  53+2  57+2  53+2  45+2  45+2  45+2  53+2  14+2   Male
# 2470   67+2  67+2  59+2  61+2  70+0  70+0  70+0  61+2  17+2   Male
# 369    74+0  74+0  77+0  74+0  75+0  75+0  75+0  74+0  25+0   Male
# 10554  52+2  52+2  55+2  53+2  46+2  46+2  46+2  53+2  17+2   Male

# %% [markdown]
# _____________
# The following dataset is a collection of **one-year** 17.125 player information distributed among 107 different columns. The majority of our data types are mostly **numericals** (52 object / 45 integers / 10 floats).
#
# Our **project goal** is to identify players who have the potential to become **the next Mbappé**. After reading the [documentation](https://www.kaggle.com/datasets/ekrembayar/fifa-21-complete-player-dataset?select=fifa21_male2.csv) we decide to proceed with the following **strategy**:
#
# 1. The **target** of our dataset will be `OVA` (overall score), which is a summary of a player's performance and potential.
# 1. The majority of the data types are **numericals**, so we will work with that.
# 3. Through **Exploratory Data Analysis** we will identify the features that contribute to this prediction.
# _____________
# In previous versions, we removed some numerical features realted to player-potential. For this one, we will keep all features related to player attributes.
#
# Also in previous versions, we converted features like `Value` and `Release_clause`; we will not use them this time, since we don't want to predict the player market value.
#
# Lastly, features such as `'height'`, `'weight'`, etc., will be converted to the metric system by removing quotation symbols or lbs.
# _____________

# %% [markdown]
# ## 02 - Cleaning the Data

# %%
data_copy = data.copy() # as best practices, we do first a copy of our dataframe

# %%
clean_columns() # Standardizes the column name from data_copy
# Out:
# Empty DataFrame
# Columns: [id, name, age, ova, nationality, club, bov, bp, position, player_photo, club_logo, flag_photo, pot, team_&_contract, height, weight, foot, growth, joined, loan_date_end, value, wage, release_clause, contract, attacking, crossing, finishing, heading_accuracy, short_passing, volleys, skill, dribbling, curve, fk_accuracy, long_passing, ball_control, movement, acceleration, sprint_speed, agility, reactions, balance, power, shot_power, jumping, stamina, strength, long_shots, mentality, aggression, interceptions, positioning, vision, penalties, composure, defending, marking, standing_tackle, sliding_tackle, goalkeeping, gk_diving, gk_handling, gk_kicking, gk_positioning, gk_reflexes, total_stats, base_stats, w/f, sm, a/w, d/w, ir, pac, sho, pas, dri, def, phy, hits, ls, st, rs, lw, lf, cf, rf, rw, lam, cam, ram, lm, lcm, cm, rcm, rm, lwb, ldm, cdm, rdm, rwb, ...]
# Index: []

# %% [markdown]
# ### Encoding
# * To easily **clean** it, we will split the dataset to get all numericals.
# * Firstly, we need to encode some columns considered as **categoricals** that are actually **numericals**
# * e.g: `height`, `weight`, etc.

# %%
# Convert height data from feet and inches to centimeters
data_copy['h_cm'] = data_copy['height'].apply(lambda x: int(x.split("'")[0])*30.48 + int(x.split("'")[1].replace('"', ''))*2.54)
# Convert weight data from pounds to kilograms
data_copy['w_kg'] = data_copy['weight'].apply(lambda x: int(x[:-3]) / 2.2046)
# Modify cells with 'K' character, leave others unchanged, turn it to integer
data_copy['hits'] = data_copy['hits'].apply(lambda x: float(x.replace('K','')) * 1000 if isinstance(x, str) and 'K' in x else x).astype(int)

# Applying lambda to:

# weak_foot 
data_copy['w_f'] = data_copy['w/f'].apply(lambda x: int(x[0]))
# skilled_moves
data_copy['sm'] = data_copy['sm'].apply(lambda x: int(x[0]) if isinstance(x, str) else x)

# international_reputation
data_copy['ir'] = data_copy['ir'].apply(lambda x: int(x[0]) if isinstance(x, str) else x)

# Visualizing the changes
data_encoded = data_copy[['h_cm', 'w_kg', 'hits', 'w_f', 'sm', 'ir']]
data_encoded.head(5)
# Out:
#      h_cm       w_kg  hits  w_f  sm  ir
# 0  182.88  82.101061     4    3   2   2
# 1  177.80  64.864374     4    4   3   1
# 2  175.26  73.029121    11    4   4   2
# 3  180.34  74.843509     3    3   1   1
# 4  170.18  68.039554   149    4   4   4

# %% [markdown]
# ### Further Encoding

# %% [markdown]
# * `a/w` stands for Attacking Work Rate
# * `d/w` stands for Defensive Work Rate
#
# **AKA.** Tendency to a player towards attack or defense.

# %%
data_f_encoding = data_copy[['a/w', 'd/w']]
data_f_encoding.head(5)
# Out:
#       a/w     d/w
# 0  Medium    High
# 1  Medium  Medium
# 2  Medium     Low
# 3     NaN     NaN
# 4    High  Medium

# %%
# Initialize the LabelEncoder object from sklearn
le = LabelEncoder()

# Fit and transform the data frame column
data_copy['a_wr'] = le.fit_transform(data_copy['a/w'])
data_copy['d_wr'] = le.fit_transform(data_copy['d/w'])

# Visualizing the changes
data_encoded_f = data_copy[['a_wr', 'd_wr']]
data_comparision_2 = pd.concat([data_f_encoding, data_encoded_f], axis=1)
data_comparision_2.head(5)
# Out:
#       a/w     d/w  a_wr  d_wr
# 0  Medium    High     2     0
# 1  Medium  Medium     2     2
# 2  Medium     Low     2     1
# 3     NaN     NaN     3     3
# 4    High  Medium     0     2

# %% [markdown]
# ### Selecting numericals / Dealing with Null values

# %%
# Create a new dataframe with only the numerical columns using select_dtypes
X_N = data_copy.select_dtypes(np.number).fillna(0) # we also deal with NaN values
X_N.head(10)
# Out:
#     id  age  ova  bov  pot  growth  attacking  crossing  finishing  \
# 0    2   33   69   71   69       0        313        75         50
# 1   16   37   71   70   71       0        337        68         64
# 2   27   33   71   71   71       0        337        80         64
# 3   36   36   68   70   82      14        264        54         70
# 4   41   36   81   82   81       0        367        75         69
# 5   61   27   66   66   70       4        271        61         53
# 6   80   38   77   77   77       0        342        80         66
# 7  241   39   78   78   78       0        380        90         70
# 8  244   35   76   78   82       6        304        72         31
# 9  246   37   80   82   80       0        394        83         65
#
#    heading_accuracy  short_passing  volleys  skill  dribbling  curve  \
# 0                59             71     58.0    338         73   65.0
# 1                61             76     68.0    369         69   79.0
# 2                41             77     75.0    387         79   84.0
# 3                60             80      0.0    255         68    0.0
# 4                54             90     79.0    408         85   80.0
# 5                42             58     57.0    276         67   61.0
# 6                43             84     69.0    406         77   83.0
# 7                60             85     75.0    402         77   87.0
# 8                75             71     55.0    258         44   56.0
# 9                72             89     85.0    393         75   74.0
#
#    fk_accuracy  long_passing  ball_control  movement  acceleration  \
# 0           60            69            71       347            68
# 1           79            71            71       305            56
# 2           77            69            78       295            48
# 3           46            64            77       176            59
# 4           70            83            90       346            61
# 5           42            44            62       406            90
# 6           80            85            81       308            54
# 7           78            81            79       337            59
# 8           33            61            64       324            64
# 9           67            90            87       338            53
#
#    sprint_speed  agility  reactions  balance  power  shot_power  jumping  \
# 0            74     68.0         69     68.0    347          74     68.0
# 1            50     62.0         65     72.0    324          75     54.0
# 2            42     71.0         59     75.0    284          72     58.0
# 3            62      0.0         55      0.0    239          63      0.0
# 4            56     79.0         75     75.0    297          67     40.0
# 5            91     75.0         65     85.0    315          71     70.0
# 6            36     67.0         70     81.0    340          77     72.0
# 7            60     72.0         76     70.0    310          71     59.0
# 8            70     51.0         72     67.0    284          47     70.0
# 9            53     68.0         82     82.0    333          88     64.0
#
#    stamina  strength  long_shots  mentality  aggression  interceptions  \
# 0       69        68          68        320          72           69.0
# 1       64        60          71        362          71           71.0
# 2       29        56          69        317          69           39.0
# 3       51        66          59        271          59           70.0
# 4       58        62          70        370          58           70.0
# 5       64        61          49        256          63           26.0
# 6       51        64          76        384          87           62.0
# 7       48        61          71        358          60           47.0
# 8       65        74          28        319          87           85.0
# 9       34        63          84        417          87           79.0
#
#    positioning  vision  penalties  composure  defending  marking  \
# 0         63.0    66.0         50        0.0        208       70
# 1         72.0    73.0         75       79.0        153       70
# 2         69.0    74.0         66        0.0         99       35
# 3         72.0     0.0         70        0.0         75       34
# 4         78.0    93.0         71       89.0        181       68
# 5         63.0    58.0         46        0.0         79       22
# 6         65.0    85.0         85       80.0        190       65
# 7         78.0    83.0         90        0.0        120       26
# 8         45.0    70.0         32        0.0        242       78
# 9         83.0    91.0         77        0.0        143       58
#
#    standing_tackle  sliding_tackle  goalkeeping  gk_diving  gk_handling  \
# 0               69            69.0           56         14            5
# 1               43            40.0           56          9           12
# 2               34            30.0           51          9            6
# 3               41             0.0           68          5           21
# 4               57            56.0           45          6           13
# 5               26            31.0           46          8           13
# 6               65            60.0           47          7           11
# 7               43            51.0           32         10            5
# 8               81            83.0           43         12            9
# 9               49            36.0           47          7           12
#
#    gk_kicking  gk_positioning  gk_reflexes  total_stats  base_stats  sm  ir  \
# 0          15              10           12         1929         408   2   2
# 1          13              11           11         1906         385   3   1
# 2          13              16            7         1770         354   4   2
# 3          64              21           21         1348         369   1   1
# 4           6              13            7         2014         420   4   4
# 5           7               9            9         1649         360   3   2
# 6           7              14            8         2017         403   4   2
# 7           7               5            5         1939         392   3   3
# 8           5               6           11         1774         378   2   3
# 9           5              15            8         2065         415   3   2
#
#    pac  sho  pas  dri  def  phy  hits    h_cm       w_kg  w_f  a_wr  d_wr
# 0   71   59   70   71   68   69     4  182.88  82.101061    3     2     0
# 1   53   69   73   69   58   63     4  177.80  64.864374    4     2     2
# 2   45   68   76   77   36   52    11  175.26  73.029121    4     2     1
# 3   61   66   66   69   47   60     3  180.34  74.843509    3     3     3
# 4   58   70   85   85   63   59   149  170.18  68.039554    4     0     2
# 5   91   56   56   67   27   63     7  172.72  73.936315    2     2     2
# 6   44   71   83   77   62   66     7  170.18  72.121927    4     2     2
# 7   60   72   85   77   41   57     9  177.80  71.214733    2     2     2
# 8   67   36   67   53   81   74     4  177.80  78.925882    3     3     3
# 9   53   76   87   79   59   61     7  170.18  71.214733    3     2     2

# %% [markdown]
# ### Dropping unnecesary features

# %% [markdown]
# From all features above, we will drop the following:
# * `id` it's just the player identifier.
# * `bov` after many attempts and previous versions, it always show high multicollinearity with `ova`, so we will drop it now.
# * `base_stats` and `total_stats` are the sum of different stats.

# %%
X_N = X_N.drop(columns=['id', 'bov', 'base_stats', 'total_stats'])

# %%
# Now, we will get a list of all column names to just quickly move the target at the end
data_headers = list(X_N.columns.values) # to get and check all column names
print("The Column Headers are :", data_headers)
# Out:
# The Column Headers are : ['age', 'ova', 'pot', 'growth', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'sm', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits', 'h_cm', 'w_kg', 'w_f', 'a_wr', 'd_wr']

# %%
# We simply move our target overall_scores to the right, for readibility and remove ID
X_N = X_N[['age', 'pot', 'growth', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 
            'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 
            'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle',
            'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'sm', 'ir', 'pac', 'sho', 'pas', 
            'dri', 'def', 'phy', 'hits', 'h_cm', 'w_kg', 'w_f', 'a_wr', 'd_wr', 'ova']]
X_N.shape
# Out:
# (17125, 59)

# %% [markdown]
# **Now**, we have a cleaned dataset with `17.125` numerical player information in `59` distinct numerical features.

# %%
X_N.sample(5)
# Out:
#        age  pot  growth  attacking  crossing  finishing  heading_accuracy  \
# 10442   22   74       9        226        60         28                48
# 3578    30   62       0        205        42         32                60
# 13457   22   71       7        266        58         32                64
# 10021   26   69       2        320        58         68                67
# 4482    27   63       0        236        42         40                45
#
#        short_passing  volleys  skill  dribbling  curve  fk_accuracy  \
# 10442             61     29.0    257         60   52.0           31
# 3578              50     21.0    211         42   37.0           31
# 13457             68     44.0    224         40   34.0           28
# 10021             61     66.0    248         63   43.0           26
# 4482              67     42.0    298         60   56.0           52
#
#        long_passing  ball_control  movement  acceleration  sprint_speed  \
# 10442            53            61       381            87            90
# 3578             50            51       285            58            56
# 13457            66            56       289            64            62
# 10021            48            68       314            65            68
# 4482             66            64       323            59            49
#
#        agility  reactions  balance  power  shot_power  jumping  stamina  \
# 10442     80.0         49     75.0    260          27     71.0       69
# 3578      55.0         55     61.0    305          60     79.0       63
# 13457     45.0         57     61.0    295          46     72.0       58
# 10021     63.0         63     55.0    340          70     63.0       70
# 4482      79.0         60     76.0    269          45     56.0       66
#
#        strength  long_shots  mentality  aggression  interceptions  \
# 10442        63          30        247          57           59.0
# 3578         74          29        245          63           62.0
# 13457        69          50        236          63           63.0
# 10021        72          65        255          48           22.0
# 4482         66          36        282          43           56.0
#
#        positioning  vision  penalties  composure  defending  marking  \
# 10442         51.0    43.0         37       50.0        184       62
# 3578          30.0    43.0         47       52.0        187       61
# 13457         34.0    39.0         37       54.0        188       59
# 10021         68.0    53.0         64       63.0         69       22
# 4482          68.0    67.0         48       51.0        149       42
#
#        standing_tackle  sliding_tackle  goalkeeping  gk_diving  gk_handling  \
# 10442               62            60.0           56         15           14
# 3578                65            61.0           52          7           14
# 13457               67            62.0           52         11           12
# 10021               27            20.0           54         12           12
# 4482                62            45.0           71         16           12
#
#        gk_kicking  gk_positioning  gk_reflexes  sm  ir  pac  sho  pas  dri  \
# 10442           9              13            5   2   1   89   30   54   63
# 3578            6              16            9   2   1   57   37   45   48
# 13457           8              11           10   2   1   63   39   56   47
# 10021           8              12           10   3   1   67   68   54   64
# 4482           14              14           15   2   1   54   42   61   64
#
#        def  phy  hits    h_cm       w_kg  w_f  a_wr  d_wr  ova
# 10442   60   64    12  177.80  68.039554    2     2     2   65
# 3578    62   69     4  185.42  82.101061    3     2     2   62
# 13457   63   65     4  185.42  78.925882    2     1     2   64
# 10021   28   66     8  187.96  76.204300    3     2     2   67
# 4482    51   61     6  177.80  78.925882    3     2     0   63

# %% [markdown]
# ## 03 - Exploratory Data Analysis

# %%
# Looking at promising talents
data_copy['pot_minus_ova'] = data_copy['pot'] - data_copy['ova'] 

# Create a new DataFrame that contains only the rows with "difference" > 10 and age < 21
talents = data_copy[(data_copy['pot_minus_ova'] > 10) & (data_copy['age'] < 21)]
talents_sorted = talents.sort_values('pot_minus_ova', ascending=False)
talents_sorted.head(3)
# Out:
#            id          name  age  ova  nationality                  club  bov  \
# 16660  257793   R. Richards   16   54      England  West Bromwich Albion   55
# 17112  259074    A. Hajdari   17   53  Switzerland         FC Basel 1893   55
# 16812  258315  B. Arrey-Mbi   17   60      Germany     Bayern München II   62
#
#        bp position                                       player_photo  \
# 16660  LM   LM CAM  https://cdn.sofifa.com/players/257/793/20_120.png
# 17112  CB       CB  https://cdn.sofifa.com/players/259/074/20_120.png
# 16812  CB    CB LB  https://cdn.sofifa.com/players/258/315/20_120.png
#
#                                               club_logo  \
# 16660     https://cdn.sofifa.com/teams/109/light_60.png
# 17112     https://cdn.sofifa.com/teams/896/light_60.png
# 16812  https://cdn.sofifa.com/teams/110679/light_60.png
#
#                                     flag_photo  pot  \
# 16660  https://cdn.sofifa.com/flags/gb-eng.png   80
# 17112      https://cdn.sofifa.com/flags/ch.png   79
# 16812      https://cdn.sofifa.com/flags/de.png   86
#
#                         team_&_contract height  weight  foot  growth  \
# 16660  West Bromwich Albion 2020 ~ 2023  5'10"  150lbs  Left      26
# 17112         FC Basel 1893 2020 ~ 2024   6'2"  176lbs  Left      26
# 16812     Bayern München II 2020 ~ 2022   6'2"  168lbs  Left      26
#
#              joined loan_date_end  value  wage release_clause     contract  \
# 16660   Aug 4, 2020           NaN  €150K   €1K          €450K  2020 ~ 2023
# 17112  Sep 14, 2020           NaN  €120K  €500          €300K  2020 ~ 2024
# 16812   Jul 1, 2020           NaN  €425K  €500            €1M  2020 ~ 2022
#
#        attacking  crossing  finishing  heading_accuracy  short_passing  \
# 16660        220        52         40                37             50
# 17112        161        31         17                53             32
# 16812        204        34         25                59             56
#
#        volleys  skill  dribbling  curve  fk_accuracy  long_passing  \
# 16660     41.0    248         59   47.0           41            43
# 17112     28.0    134         22   30.0           29            25
# 16812     30.0    207         49   31.0           29            44
#
#        ball_control  movement  acceleration  sprint_speed  agility  reactions  \
# 16660            58       313            72            64     62.0         43
# 17112            28       262            58            61     45.0         48
# 16812            54       324            66            70     68.0         52
#
#        balance  power  shot_power  jumping  stamina  strength  long_shots  \
# 16660     72.0    251          53     51.0       54        45          48
# 17112     50.0    252          38     66.0       56        68          24
# 16812     68.0    273          38     78.0       62        71          24
#
#        mentality  aggression  interceptions  positioning  vision  penalties  \
# 16660        194          33           16.0         39.0    55.0         51
# 17112        195          51           53.0         28.0    27.0         36
# 16812        228          63           53.0         35.0    44.0         33
#
#        composure  defending  marking  standing_tackle  sliding_tackle  \
# 16660       48.0         84       22               29            33.0
# 17112       39.0        157       47               58            52.0
# 16812       56.0        180       55               64            61.0
#
#        goalkeeping  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 16660           43         10            8           8               8
# 17112           46         12            9           9              11
# 16812           50         13            9           8              12
#
#        gk_reflexes  total_stats  base_stats  w/f  sm     a/w     d/w  ir  pac  \
# 16660            9         1353         293  3 ★   2  Medium  Medium   1   68
# 17112            5         1207         259  3 ★   2     Low  Medium   1   60
# 16812            8         1466         322  3 ★   2  Medium  Medium   1   68
#
#        sho  pas  dri  def  phy  hits    ls    st    rs    lw    lf    cf  \
# 16660   45   50   59   26   45    83  48+2  48+2  48+2  53+0  51+0  51+0
# 17112   25   30   29   53   62    37  36+2  36+2  36+2  32+0  32+0  32+0
# 16812   29   45   54   58   68   720  46+2  46+2  46+2  47+0  46+0  46+0
#
#          rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm  \
# 16660  51+0  53+0  52+2  52+2  52+2  53+2  47+2  47+2  47+2  53+2  43+2  38+2
# 17112  32+0  32+0  31+2  31+2  31+2  34+2  33+2  33+2  33+2  34+2  45+2  44+2
# 16812  46+0  47+0  48+2  48+2  48+2  49+2  49+2  49+2  49+2  49+2  55+2  56+2
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk gender    h_cm  \
# 16660  38+2  38+2  43+2  41+2  34+2  34+2  34+2  41+2  12+2   Male  177.80
# 17112  44+2  44+2  45+2  48+2  53+2  53+2  53+2  48+2  14+2   Male  187.96
# 16812  56+2  56+2  55+2  57+2  60+2  60+2  60+2  57+2  15+2   Male  187.96
#
#             w_kg  w_f  a_wr  d_wr  pot_minus_ova
# 16660  68.039554    3     2     2             26
# 17112  79.833076    3     1     2             26
# 16812  76.204300    3     2     2             26

# %%
# Looking at Overall Score Plaer with rating >80
mvps = data_copy[(data_copy['ova'] > 80)]

# Sort the MVPs
mvps_sorted = mvps.sort_values('ova', ascending=False)
mvps_sorted.head(5)
# Out:
#           id               name  age  ova nationality                 club  \
# 752   158023           L. Messi   33   93   Argentina         FC Barcelona
# 142    20801  Cristiano Ronaldo   35   92    Portugal             Juventus
# 2287  188545     R. Lewandowski   31   91      Poland    FC Bayern München
# 2650  190871          Neymar Jr   28   91      Brazil  Paris Saint-Germain
# 2871  192985       K. De Bruyne   29   91     Belgium      Manchester City
#
#       bov   bp  position                                       player_photo  \
# 752    93   RW  RW ST CF  https://cdn.sofifa.com/players/158/023/20_120.png
# 142    92   ST     ST LW  https://cdn.sofifa.com/players/020/801/20_120.png
# 2287   91   ST        ST  https://cdn.sofifa.com/players/188/545/20_120.png
# 2650   91   LW    LW CAM  https://cdn.sofifa.com/players/190/871/20_120.png
# 2871   91  CAM    CAM CM  https://cdn.sofifa.com/players/192/985/20_120.png
#
#                                           club_logo  \
# 752   https://cdn.sofifa.com/teams/241/light_60.png
# 142    https://cdn.sofifa.com/teams/45/light_60.png
# 2287   https://cdn.sofifa.com/teams/21/light_60.png
# 2650   https://cdn.sofifa.com/teams/73/light_60.png
# 2871   https://cdn.sofifa.com/teams/10/light_60.png
#
#                                flag_photo  pot  \
# 752   https://cdn.sofifa.com/flags/ar.png   93
# 142   https://cdn.sofifa.com/flags/pt.png   92
# 2287  https://cdn.sofifa.com/flags/pl.png   91
# 2650  https://cdn.sofifa.com/flags/br.png   91
# 2871  https://cdn.sofifa.com/flags/be.png   91
#
#                       team_&_contract height  weight   foot  growth  \
# 752          FC Barcelona 2004 ~ 2021   5'7"  159lbs   Left       0
# 142              Juventus 2018 ~ 2022   6'2"  183lbs  Right       0
# 2287    FC Bayern München 2014 ~ 2023   6'0"  176lbs  Right       0
# 2650  Paris Saint-Germain 2017 ~ 2022   5'9"  150lbs  Right       0
# 2871      Manchester City 2015 ~ 2023  5'11"  154lbs  Right       0
#
#             joined loan_date_end   value   wage release_clause     contract  \
# 752    Jul 1, 2004           NaN  €67.5M  €560K        €138.4M  2004 ~ 2021
# 142   Jul 10, 2018           NaN    €46M  €220K         €75.9M  2018 ~ 2022
# 2287   Jul 1, 2014           NaN    €80M  €240K          €132M  2014 ~ 2023
# 2650   Aug 3, 2017           NaN    €90M  €270K        €166.5M  2017 ~ 2022
# 2871  Aug 30, 2015           NaN    €87M  €370K          €161M  2015 ~ 2023
#
#       attacking  crossing  finishing  heading_accuracy  short_passing  \
# 752         429        85         95                70             91
# 142         437        84         95                90             82
# 2287        423        71         94                85             84
# 2650        408        85         87                62             87
# 2871        407        94         82                55             94
#
#       volleys  skill  dribbling  curve  fk_accuracy  long_passing  \
# 752      88.0    470         96   93.0           94            91
# 142      86.0    414         88   81.0           76            77
# 2287     89.0    407         85   79.0           85            70
# 2650     87.0    448         95   88.0           89            81
# 2871     82.0    441         88   85.0           83            93
#
#       ball_control  movement  acceleration  sprint_speed  agility  reactions  \
# 752             96       451            91            80     91.0         94
# 142             92       431            87            91     87.0         95
# 2287            88       407            77            78     77.0         93
# 2650            95       453            94            89     96.0         91
# 2871            92       398            77            76     78.0         91
#
#       balance  power  shot_power  jumping  stamina  strength  long_shots  \
# 752      95.0    389          86     68.0       72        69          94
# 142      71.0    444          94     95.0       84        78          93
# 2287     82.0    420          89     84.0       76        86          85
# 2650     83.0    357          80     62.0       81        50          84
# 2871     76.0    408          91     63.0       89        74          91
#
#       mentality  aggression  interceptions  positioning  vision  penalties  \
# 752         347          44           40.0         93.0    95.0         75
# 142         353          63           29.0         95.0    82.0         84
# 2287        391          81           49.0         94.0    79.0         88
# 2650        356          51           36.0         87.0    90.0         92
# 2871        408          76           66.0         88.0    94.0         84
#
#       composure  defending  marking  standing_tackle  sliding_tackle  \
# 752        96.0         91       32               35            24.0
# 142        95.0         84       28               32            24.0
# 2287       88.0         96       35               42            19.0
# 2650       93.0         94       35               30            29.0
# 2871       91.0        186       68               65            53.0
#
#       goalkeeping  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 752            54          6           11          15              14
# 142            58          7           11          15              14
# 2287           51         15            6          12               8
# 2650           59          9            9          15              15
# 2871           56         15           13           5              10
#
#       gk_reflexes  total_stats  base_stats  w/f  sm     a/w     d/w  ir  pac  \
# 752             8         2231         466  4 ★   4  Medium     Low   5   85
# 142            11         2221         464  4 ★   5    High     Low   5   89
# 2287           10         2195         457  4 ★   4    High  Medium   4   78
# 2650           11         2175         451  5 ★   5    High  Medium   5   91
# 2871           13         2304         485  5 ★   4    High    High   4   76
#
#       sho  pas  dri  def  phy  hits    ls    st    rs    lw    lf    cf    rf  \
# 752    92   91   95   38   65   830  89+3  89+3  89+3  92+0  93+0  93+0  93+0
# 142    93   81   89   35   77   750  91+1  91+1  91+1  89+0  91+0  91+0  91+0
# 2287   91   78   85   43   82   487  89+2  89+2  89+2  85+0  87+0  87+0  87+0
# 2650   85   86   94   36   59   546  84+3  84+3  84+3  90+0  89+0  89+0  89+0
# 2871   86   93   88   64   78   406  83+3  83+3  83+3  88+0  88+0  88+0  88+0
#
#         rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm  \
# 752   92+0  93+0  93+0  93+0  91+2  87+3  87+3  87+3  91+2  66+3  65+3  65+3
# 142   89+0  88+3  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3
# 2287  85+0  85+3  85+3  85+3  83+3  79+3  79+3  79+3  83+3  64+3  65+3  65+3
# 2650  90+0  90+1  90+1  90+1  90+1  83+3  83+3  83+3  90+1  67+3  62+3  62+3
# 2871  88+0  89+2  89+2  89+2  89+2  89+2  89+2  89+2  89+2  79+3  80+3  80+3
#
#        rdm   rwb    lb   lcb    cb   rcb    rb    gk gender    h_cm  \
# 752   65+3  66+3  62+3  52+3  52+3  52+3  62+3  19+3   Male  170.18
# 142   61+3  65+3  61+3  54+3  54+3  54+3  61+3  20+3   Male  187.96
# 2287  65+3  64+3  61+3  60+3  60+3  60+3  61+3  19+3   Male  182.88
# 2650  62+3  67+3  62+3  49+3  49+3  49+3  62+3  20+3   Male  175.26
# 2871  80+3  79+3  75+3  69+3  69+3  69+3  75+3  21+3   Male  180.34
#
#            w_kg  w_f  a_wr  d_wr  pot_minus_ova
# 752   72.121927    4     2     1              0
# 142   83.008255    4     0     1              0
# 2287  79.833076    4     0     2              0
# 2650  68.039554    5     0     2              0
# 2871  69.853942    5     0     0              0

# %%
# create a dataframe with 'name' and 'value' columns
df = pd.DataFrame(data_copy, columns=['name', 'value'])

# select the rows for the six specific players you want to plot
players = ['K. Mbappé', 'Neymar Jr', 'K. De Bruyne', 'R. Richards', 'A. Hajdari','B. Arrey-Mbi']
df_players = df[df['name'].isin(players)]

# create a bar chart
plt.figure(figsize=(8,6))
bars = plt.bar(df_players['name'], df_players['value'])
plt.ylabel('Value in €100Mio')
plt.title('Comparison of MVPs and Talents')

# show the chart
plt.show()

# %%
# Group the data by country and count the number of players in each country
mvps_by_country = mvps.groupby('nationality')['name'].count().sort_values(ascending=False)

# Plot a bar chart of the top 10 countries with the most players
mvps_by_country.head(10).plot(kind='bar')

# Add labels and a title to the chart
plt.xlabel('Country')
plt.ylabel('Number of players')
plt.title('Top 10 countries with the most valuable players')

# Display the chart
plt.show()

# %%
# Group the data by country and count the number of players in each country
talents_by_country = talents.groupby('nationality')['name'].count().sort_values(ascending=False)

# Plot a bar chart of the top 10 countries with the most players
talents_by_country.head(10).plot(kind='bar')

# Add labels and a title to the chart
plt.xlabel('Country')
plt.ylabel('Number of players')
plt.title('Top 10 countries with the most promising talents')

# Display the chart
plt.show()

# %% [markdown]
# ## 04 - Processing Data

# %% [markdown]
# ### Dealing with outliers

# %%
X_N.shape
# Out:
# (17125, 59)

# %%
for column in X_N:
    Q1 = X_N[column].quantile(0.25)
    Q3 = X_N[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    X_N = X_N[(X_N[column] >= lower_bound) & (X_N[column] <= upper_bound)]

# %%
fig, ax = plt.subplots(figsize=(30, 12))
sns.boxplot(data=X_N, orient="h", ax=ax, showfliers=True, whis=1.5)

# Set the x-axis label
ax.set_ylabel("Features")
# Set the title of the plot
ax.set_title("Features Outliers")
# Adjust the font size of the x-axis ticks
ax.tick_params(axis='x', labelsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### Checking normal distributions

# %%
# set color palette
colors = ['#0072B2'] # blue

# plot normalized features in a grid
fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 16)) # nrows to 5, ncols to 6 to plot our 26 features
for i, ax in enumerate(axes.flat):
    if i >= len(X_N.columns):
        break
    sns.histplot(X_N.iloc[:, i], ax=ax, color=colors[i % len(colors)], kde=True)
    sns.kdeplot(X_N.iloc[:, i], ax=ax, color='#999999', linewidth=2)
    ax.set_title(X_N.columns[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# The majority of our features seems to have a bell-shape curve, so we will use **MinMaxScaler** for normalization.

# %% [markdown]
# ### X-Y Split

# %%
# We do X-Y SPLIT BEFORE normalizing. ~ Xisca. We don't want to normalize the target :)
Y = X_N['sinister']
X = X_N.drop(['sinister'], axis=1)

# %% [markdown]
# ### Normalizing the data

# %%
scaler = MinMaxScaler()
X_minmax = scaler.fit_transform(X)

# Making it a dataframe
X_minmax = pd.DataFrame(X_minmax, columns=X.columns)

# %%
# Checking again their distributions

# set color palette
colors = ['#0072B2'] # blue

# plot normalized features in a grid
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 16)) # nrows to 5, ncols to 6 to plot our 26 features
for i, ax in enumerate(axes.flat):
    if i >= len(X_minmax.columns):
        break
    sns.histplot(X_minmax.iloc[:, i], ax=ax, color=colors[i % len(colors)], kde=True)
    sns.kdeplot(X_minmax.iloc[:, i], ax=ax, color='#999999', linewidth=2)
    ax.set_title(X_minmax.columns[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# Some features such as `value`, `wage` and `release_clouse`, `hits`, still does not show a normal distribution after normalization.
# We will adress this specically first doing log transformations:

# %%
# We apply log transformations
X_minmax['release_clause'] = np.log(X_minmax['release_clause'])
X_minmax['value'] = np.log(X_minmax['value'])
X_minmax['goalkeeping'] = np.log(X_minmax['goalkeeping'])
X_minmax['ir'] = np.log(X_minmax['ir'])
X_minmax['hits'] = np.log(X_minmax['hits'])

# %%
# Checking again their distributions

# set color palette
colors = ['#0072B2'] # blue

# plot normalized features in a grid
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 16)) # nrows to 5, ncols to 6 to plot our 26 features
for i, ax in enumerate(axes.flat):
    if i >= len(X_minmax.columns):
        break
    sns.histplot(X_minmax.iloc[:, i], ax=ax, color=colors[i % len(colors)], kde=True)
    sns.kdeplot(X_minmax.iloc[:, i], ax=ax, color='#999999', linewidth=2)
    ax.set_title(X_minmax.columns[i])
plt.tight_layout()
plt.show()

# %%
# We apply square root transformation
X_minmax['growth'] = np.sqrt(X_minmax['growth'])
X_minmax['wage'] = np.sqrt(X_minmax['wage'])

# %%
# Checking again their distributions

# set color palette
colors = ['#0072B2'] # blue

# plot normalized features in a grid
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 16)) # nrows to 5, ncols to 6 to plot our 26 features
for i, ax in enumerate(axes.flat):
    if i >= len(X_minmax.columns):
        break
    sns.histplot(X_minmax.iloc[:, i], ax=ax, color=colors[i % len(colors)], kde=True)
    sns.kdeplot(X_minmax.iloc[:, i], ax=ax, color='#999999', linewidth=2)
    ax.set_title(X_minmax.columns[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dealing with multicollinearity

# %%
# This might be a confusing step, we will quickly normalize again all numerical data included the target
# This can improve the performance of the correlation matrix
# If there is any feature to drop, we will do it in X_minmax, after comparing

# Correlation Matrix
X_corr = scaler.fit_transform(X_N)

# Making it a dataframe
X_corr = pd.DataFrame(X_corr, columns=X_N.columns)

# We apply log transformations
X_corr['release_clause'] = np.log(X_corr['release_clause'])
X_corr['value'] = np.log(X_corr['value'])
X_corr['goalkeeping'] = np.log(X_corr['goalkeeping'])
X_corr['ir'] = np.log(X_corr['ir'])
X_corr['hits'] = np.log(X_corr['hits'])

# We apply square root transformation
X_corr['growth'] = np.sqrt(X_corr['growth'])
X_corr['wage'] = np.sqrt(X_corr['wage'])

# Show Matrix
X_corr = round(X_corr.corr(), 4)
X_corr
# Out:
#                    age     ova     bov     pot  growth   value    wage  \
# age             1.0000  0.5193  0.4581 -0.2459 -0.8880  0.2268  0.3019
# ova             0.5193  1.0000  0.9855  0.5814 -0.5780  0.9294  0.7254
# bov             0.4581  0.9855  1.0000  0.6184 -0.5155  0.9385  0.7239
# pot            -0.2459  0.5814  0.6184  1.0000  0.3099  0.7256  0.4816
# growth         -0.8880 -0.5780 -0.5155  0.3099  1.0000 -0.3450 -0.3660
# value           0.2268  0.9294  0.9385  0.7256 -0.3450  1.0000  0.7458
# wage            0.3019  0.7254  0.7239  0.4816 -0.3660  0.7458  1.0000
# release_clause  0.1776  0.9115  0.9241  0.7754 -0.2840  0.9905  0.7472
# attacking       0.1822  0.4275  0.4613  0.2271 -0.2777  0.4626  0.3682
# skill           0.1670  0.4374  0.4703  0.2586 -0.2588  0.4736  0.3693
# movement       -0.0581  0.2962  0.3295  0.2518 -0.0842  0.3936  0.2483
# power           0.3092  0.5439  0.5702  0.2138 -0.4165  0.5421  0.4261
# mentality       0.2716  0.4925  0.5215  0.2371 -0.3441  0.4908  0.4068
# defending       0.1142  0.2492  0.2691  0.1381 -0.1438  0.2344  0.2038
# goalkeeping     0.1301  0.0220 -0.0264 -0.0377 -0.0638 -0.0607 -0.0372
# base_stats      0.4146  0.8297  0.8272  0.4642 -0.4941  0.7834  0.5971
# total_stats     0.2788  0.6039  0.6318  0.3206 -0.3844  0.6137  0.4840
# sm              0.0691  0.3412  0.3699  0.2352 -0.1681  0.4083  0.3073
# ir              0.1404  0.4359  0.4123  0.4235  0.0635  0.2562  0.2084
# hits           -0.1153  0.5116  0.5483  0.7157  0.1026  0.6320  0.5268
# h_cm            0.0934  0.0281  0.0167 -0.0211 -0.0459 -0.0215  0.0385
# w_kg            0.2592  0.1523  0.1327 -0.0425 -0.2156  0.0600  0.0987
# w_f             0.0804  0.1962  0.2076  0.1319 -0.1064  0.2090  0.1544
# a_wr           -0.0339 -0.1691 -0.1730 -0.1058  0.0944 -0.2021 -0.1482
# d_wr           -0.1260 -0.1562 -0.1643 -0.0396  0.1458 -0.1421 -0.1412
# sinister        0.1194  0.2109  0.2118  0.1142 -0.1417  0.2096  0.1627
#
#                 release_clause  attacking   skill  movement   power  \
# age                     0.1776     0.1822  0.1670   -0.0581  0.3092
# ova                     0.9115     0.4275  0.4374    0.2962  0.5439
# bov                     0.9241     0.4613  0.4703    0.3295  0.5702
# pot                     0.7754     0.2271  0.2586    0.2518  0.2138
# growth                 -0.2840    -0.2777 -0.2588   -0.0842 -0.4165
# value                   0.9905     0.4626  0.4736    0.3936  0.5421
# wage                    0.7472     0.3682  0.3693    0.2483  0.4261
# release_clause          1.0000     0.4559  0.4681    0.3899  0.5186
# attacking               0.4559     1.0000  0.9280    0.6929  0.8229
# skill                   0.4681     0.9280  1.0000    0.7256  0.7526
# movement                0.3899     0.6929  0.7256    1.0000  0.5594
# power                   0.5186     0.8229  0.7526    0.5594  1.0000
# mentality               0.4819     0.8873  0.8839    0.6084  0.8220
# defending               0.2363     0.3132  0.3703    0.1747  0.3642
# goalkeeping            -0.0675    -0.7411 -0.6905   -0.5583 -0.5518
# base_stats              0.7634     0.4257  0.5000    0.4471  0.5730
# total_stats             0.5999     0.9030  0.9276    0.7365  0.8652
# sm                      0.4022     0.7664  0.7908    0.6995  0.5835
# ir                      0.3111     0.0821  0.0821    0.0185  0.0273
# hits                    0.6743     0.2659  0.2812    0.2773  0.2633
# h_cm                   -0.0256    -0.3542 -0.4558   -0.6336 -0.1313
# w_kg                    0.0435    -0.2590 -0.3568   -0.5394  0.0011
# w_f                     0.2044     0.3530  0.3533    0.2806  0.2883
# a_wr                   -0.1969    -0.3286 -0.3102   -0.3715 -0.2985
# d_wr                   -0.1370    -0.1836 -0.1590   -0.0906 -0.2515
# sinister                0.2035     0.2661  0.2735    0.2133  0.2218
#
#                 mentality  defending  goalkeeping  base_stats  total_stats  \
# age                0.2716     0.1142       0.1301      0.4146       0.2788
# ova                0.4925     0.2492       0.0220      0.8297       0.6039
# bov                0.5215     0.2691      -0.0264      0.8272       0.6318
# pot                0.2371     0.1381      -0.0377      0.4642       0.3206
# growth            -0.3441    -0.1438      -0.0638     -0.4941      -0.3844
# value              0.4908     0.2344      -0.0607      0.7834       0.6137
# wage               0.4068     0.2038      -0.0372      0.5971       0.4840
# release_clause     0.4819     0.2363      -0.0675      0.7634       0.5999
# attacking          0.8873     0.3132      -0.7411      0.4257       0.9030
# skill              0.8839     0.3703      -0.6905      0.5000       0.9276
# movement           0.6084     0.1747      -0.5583      0.4471       0.7365
# power              0.8220     0.3642      -0.5518      0.5730       0.8652
# mentality          1.0000     0.5903      -0.7005      0.5156       0.9468
# defending          0.5903     1.0000      -0.4829      0.2204       0.5263
# goalkeeping       -0.7005    -0.4829       1.0000      0.0823      -0.6119
# base_stats         0.5156     0.2204       0.0823      1.0000       0.6766
# total_stats        0.9468     0.5263      -0.6119      0.6766       1.0000
# sm                 0.6606     0.1415      -0.5619      0.3650       0.7162
# ir                 0.1010    -0.0316      -0.0299      0.2161       0.0847
# hits               0.2671     0.1174      -0.0597      0.4322       0.3450
# h_cm              -0.3035    -0.0504       0.3352     -0.1219      -0.3685
# w_kg              -0.2026    -0.0392       0.3144      0.0045      -0.2476
# w_f                0.2903    -0.0084      -0.2018      0.2109       0.3206
# a_wr              -0.2774    -0.0347       0.2114     -0.2192      -0.3242
# d_wr              -0.2512    -0.2407       0.1747     -0.1098      -0.2259
# sinister           0.2123    -0.0507      -0.0998      0.2129       0.2494
#
#                     sm      ir    hits    h_cm    w_kg     w_f    a_wr  \
# age             0.0691  0.1404 -0.1153  0.0934  0.2592  0.0804 -0.0339
# ova             0.3412  0.4359  0.5116  0.0281  0.1523  0.1962 -0.1691
# bov             0.3699  0.4123  0.5483  0.0167  0.1327  0.2076 -0.1730
# pot             0.2352  0.4235  0.7157 -0.0211 -0.0425  0.1319 -0.1058
# growth         -0.1681  0.0635  0.1026 -0.0459 -0.2156 -0.1064  0.0944
# value           0.4083  0.2562  0.6320 -0.0215  0.0600  0.2090 -0.2021
# wage            0.3073  0.2084  0.5268  0.0385  0.0987  0.1544 -0.1482
# release_clause  0.4022  0.3111  0.6743 -0.0256  0.0435  0.2044 -0.1969
# attacking       0.7664  0.0821  0.2659 -0.3542 -0.2590  0.3530 -0.3286
# skill           0.7908  0.0821  0.2812 -0.4558 -0.3568  0.3533 -0.3102
# movement        0.6995  0.0185  0.2773 -0.6336 -0.5394  0.2806 -0.3715
# power           0.5835  0.0273  0.2633 -0.1313  0.0011  0.2883 -0.2985
# mentality       0.6606  0.1010  0.2671 -0.3035 -0.2026  0.2903 -0.2774
# defending       0.1415 -0.0316  0.1174 -0.0504 -0.0392 -0.0084 -0.0347
# goalkeeping    -0.5619 -0.0299 -0.0597  0.3352  0.3144 -0.2018  0.2114
# base_stats      0.3650  0.2161  0.4322 -0.1219  0.0045  0.2109 -0.2192
# total_stats     0.7162  0.0847  0.3450 -0.3685 -0.2476  0.3206 -0.3242
# sm              1.0000  0.0079  0.2885 -0.4241 -0.3500  0.3270 -0.3287
# ir              0.0079  1.0000  0.2095  0.0338  0.0257  0.0803  0.0588
# hits            0.2885  0.2095  1.0000  0.0032 -0.0068  0.1385 -0.1485
# h_cm           -0.4241  0.0338  0.0032  1.0000  0.7658 -0.1641  0.2103
# w_kg           -0.3500  0.0257 -0.0068  0.7658  1.0000 -0.1202  0.1616
# w_f             0.3270  0.0803  0.1385 -0.1641 -0.1202  1.0000 -0.1400
# a_wr           -0.3287  0.0588 -0.1485  0.2103  0.1616 -0.1400  1.0000
# d_wr           -0.1001  0.0362 -0.0797  0.0072 -0.0323 -0.0435  0.1213
# sinister        0.2824  0.0846  0.1334 -0.1144 -0.0725  0.7690 -0.1403
#
#                   d_wr  sinister
# age            -0.1260    0.1194
# ova            -0.1562    0.2109
# bov            -0.1643    0.2118
# pot            -0.0396    0.1142
# growth          0.1458   -0.1417
# value          -0.1421    0.2096
# wage           -0.1412    0.1627
# release_clause -0.1370    0.2035
# attacking      -0.1836    0.2661
# skill          -0.1590    0.2735
# movement       -0.0906    0.2133
# power          -0.2515    0.2218
# mentality      -0.2512    0.2123
# defending      -0.2407   -0.0507
# goalkeeping     0.1747   -0.0998
# base_stats     -0.1098    0.2129
# total_stats    -0.2259    0.2494
# sm             -0.1001    0.2824
# ir              0.0362    0.0846
# hits           -0.0797    0.1334
# h_cm            0.0072   -0.1144
# w_kg           -0.0323   -0.0725
# w_f            -0.0435    0.7690
# a_wr            0.1213   -0.1403
# d_wr            1.0000   -0.0306
# sinister       -0.0306    1.0000

# %%
# Correlation Matrix-Heatmap Plot
mask = np.zeros_like(X_corr)
mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix
f, ax = plt.subplots(figsize=(25, 15))
sns.set(font_scale=1.5) # increase font size
ax = sns.heatmap(X_corr, mask=mask, annot=True, annot_kws={"size": 12}, linewidths=.5, cmap="coolwarm", fmt=".2f", ax=ax) # round to 2 decimal places
ax.set_title("Dealing with Multicollinearity", fontsize=20) # add title
plt.show()

# %% [markdown]
# If we look at top of our heatmap, the more correlated variables to our`sinister` target are; overall rating (`ova`), `attacking`, `power`, `value` and `wage`.
# Now, we want to deal with multicollinearity, looking for areas of high correlation.
# * `ova` seems to be highly correlated to `bov`. We will proceed to drop `bov`, since `ova` has better correlation with our target.

# %%
X_minmax = X_minmax.drop(columns=['bov'])

# %%
X_minmax.shape
# Out:
# (1452, 24)

# %%
X_minmax['sinister'] = X_N['sinister']

# %%
X_minmax.shape
# Out:
# (1452, 25)

# %%
X_minmax.dropna(0)
X_minmax.fillna(0)
Y = X_minmax['sinister']
X = X_minmax.drop(['sinister'], axis=1)

# %% [markdown]
# Our final dataset for the Linear Regression model contains `24` different features from `17.071` different soccer players.

# %% [markdown]
# ## 05 - Modeling

# %% [markdown]
# ### Train-Test Split

# %%
# We define train and test for X and Y
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) 
# test_size = We give 30% for testing and 70% for testing
# random_state = it'll improve the model to divide always the model in the same way

# %%
len(X)*0.7 # Len before the test
# Out:
# 1016.4

# %%
len(X_test) # Len after the test
# Out:
# 436

# %%
model = LinearRegression() # We have the model
model.fit(X_train,y_train) # We fit the training data into the model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7696\339685317.py in <module>
#       1 model = LinearRegression() # We have the model
# ----> 2 model.fit(X_train,y_train) # We fit the training data into the model
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     977     )
#     978
# --> 979     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     980
#     981     check_consistent_length(X, y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _check_y(y, multi_output, y_numeric)
#     987     """Isolated part of check_X_y dedicated to y validation"""
#     988     if multi_output:
# --> 989         y = check_array(
#     990             y, accept_sparse="csr", force_all_finite=True, ensure_2d=False, dtype=None
#     991         )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# ## 06 - Model Validation

# %%
predictions = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7696\4109673188.py in <module>
# ----> 1 predictions = model.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#     348     def predict(self, X):
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
r2_score(y_test, predictions), mean_squared_error(y_test, predictions, squared=False), mean_squared_error(y_test, predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7696\2485441672.py in <module>
# ----> 1 r2_score(y_test, predictions), mean_squared_error(y_test, predictions, squared=False), mean_squared_error(y_test, predictions)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     787     -3.0
#     788     """
# --> 789     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     790         y_true, y_pred, multioutput
#     791     )
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [436, 5122]

# %%
r2 = r2_score(y_test, predictions)
RMSE = mean_squared_error(y_test, predictions, squared=False)
MSE = mean_squared_error(y_test, predictions)
MAE = mean_absolute_error(y_test, predictions)

print("R2 = ", r2)
print("RMSE = ", RMSE)
print("The value of the metric MSE is ", MSE)
print("MAE = ", MAE)
# Out:
# R2 =  0.5997863302419705
# RMSE =  0.24065604306849298
# The value of the metric MSE is  0.05791533106538435
# MAE =  0.22303308998869614

# %% [markdown]
# Our model has a R-squared (`R2`) of `0.61`, which explains 61% of the variance of the data
# Root Mean Squarred Error (`RMSE`), Mean Squarred Error `MSE` and Mean Absolute Error `MAE` are really small, meaning that the predicted values are close to the actual values.

# %% [markdown]
# ### Present results

# %%
# Dataframe for true, predicted and absolute difference values
results = pd.DataFrame()
results['true'] = y_test
results['pred'] = predictions
results['diff'] = results.apply(lambda x: abs(x['true'] - x['pred']), axis=1)

# Scale the true and predicted values to be between 0 and 1
results['true_scaled'] = (results['true'] - results['true'].min()) / (results['true'].max() - results['true'].min())
results['pred_scaled'] = (results['pred'] - results['pred'].min()) / (results['pred'].max() - results['pred'].min())

# %%
# Create the plot with regression line
sns.set_style('darkgrid')
sns.regplot(x='true_scaled', y='pred_scaled', data=results, color='black', scatter_kws={'s': 10, 'color': '#3498db'})
plt.xlabel('Linear Regression', fontsize=12, color='#34495e')
plt.ylabel('Predictions', fontsize=12, color='#34495e')
plt.title('True Vs Predicted Values', fontsize=14, color='#34495e')
plt.xticks(fontsize=10, color='#34495e')
plt.yticks(fontsize=10, color='#34495e')
plt.tight_layout()
plt.show()

# %%
## MEH! not good. Needs to be fixed... AGAIN! xD

# %% [markdown]
# ## 07 - Reporting

# %%
X_N.iloc[[0]]
# Out:
#    age  ova  bov  pot  growth     value    wage  release_clause  attacking  \
# 0   33   69   71   69       0  625000.0  7000.0             0.0        313
#
#    skill  movement  power  mentality  defending  goalkeeping  base_stats  \
# 0    338       347    347        320        208           56         408
#
#    total_stats  sm  ir  hits    h_cm       w_kg  w_f  a_wr  d_wr  sinister
# 0         1929   2   2     4  182.88  82.101061    3     2     0         0

# %%
results.iloc[[0]]
# Out:
#       true      pred      diff  true_scaled  pred_scaled
# 6062     0  0.148611  0.148611          0.0     0.439567

# %%
# Creating a new 
names = data_copy.loc[results.index.to_list(), ["id","name"]]
names.head(10)
# Out:
#            id             name
# 6062   214394       W. Barrios
# 1154   170664     C. Rodríguez
# 5190   209852      B. Galloway
# 9485   232447       Y. Rokutan
# 5933   213666  R. Loftus-Cheek
# 1093   169432         M. Lacen
# 6116   214772      N. Pasquini
# 12402  242588      R. Sugimoto
# 13811  246909        T. Suzuki
# 16518  257294        S. Hopeau

# %%
# Merging with the results
test = pd.concat([names, results], axis=1)
test.head(10)
# Out:
#            id             name  true      pred      diff  true_scaled  \
# 6062   214394       W. Barrios     0  0.148611  0.148611          0.0
# 1154   170664     C. Rodríguez     0  0.267390  0.267390          0.0
# 5190   209852      B. Galloway     0  0.145378  0.145378          0.0
# 9485   232447       Y. Rokutan     0 -0.608028  0.608028          0.0
# 5933   213666  R. Loftus-Cheek     0  0.255959  0.255959          0.0
# 1093   169432         M. Lacen     0  0.228936  0.228936          0.0
# 6116   214772      N. Pasquini     0 -0.251636  0.251636          0.0
# 12402  242588      R. Sugimoto     0  0.212608  0.212608          0.0
# 13811  246909        T. Suzuki     0 -0.275147  0.275147          0.0
# 16518  257294        S. Hopeau     0  0.160702  0.160702          0.0
#
#        pred_scaled
# 6062      0.439567
# 1154      0.500071
# 5190      0.437921
# 9485      0.054151
# 5933      0.494248
# 1093      0.480483
# 6116      0.235690
# 12402     0.472166
# 13811     0.223714
# 16518     0.445726

# %%
test[test.name=='C. Baker-Richardson']
# Out:
# Empty DataFrame
# Columns: [id, name, true, pred, diff, true_scaled, pred_scaled]
# Index: []

# %%
data_copy[data_copy.name=='C. Baker-Richardson']
# Out:
#           id                 name  age  ova nationality                club  \
# 6932  220893  C. Baker-Richardson   23   61     England  Accrington Stanley
#
#       bov  bp position                                       player_photo  \
# 6932   62  ST       ST  https://cdn.sofifa.com/players/220/893/20_120.png
#
#                                              club_logo  \
# 6932  https://cdn.sofifa.com/teams/110313/light_60.png
#
#                                    flag_photo  pot  \
# 6932  https://cdn.sofifa.com/flags/gb-eng.png   68
#
#                               team_&_contract height  weight   foot  growth  \
# 6932  Accrington Stanley Jun 30, 2020 On Loan   6'2"  161lbs  Right       7
#
#             joined     value    wage  release_clause              contract  \
# 6932  Aug 14, 2017  350000.0  1000.0             NaN  Jun 30, 2020 On Loan
#
#       attacking  crossing  finishing  heading_accuracy  short_passing  \
# 6932        248        28         64                58             51
#
#       volleys  skill  dribbling  curve  fk_accuracy  long_passing  \
# 6932     47.0    195         49   35.0           23            30
#
#       ball_control  movement  acceleration  sprint_speed  agility  reactions  \
# 6932            58       300            62            69     51.0         58
#
#       balance  power  shot_power  jumping  stamina  strength  long_shots  \
# 6932     60.0    279          63     54.0       56        64          42
#
#       mentality  aggression  interceptions  positioning  vision  penalties  \
# 6932        226          42           16.0         64.0    43.0         61
#
#       composure  defending  marking  standing_tackle  sliding_tackle  \
# 6932       54.0         41       10               17            14.0
#
#       goalkeeping  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 6932           58         12           15           8               9
#
#       gk_reflexes  total_stats  base_stats  w/f  sm     a/w     d/w  ir  pac  \
# 6932           14         1347         292  3 ★   2  Medium  Medium   1   66
#
#       sho  pas  dri  def  phy  hits    ls    st    rs    lw    lf    cf    rf  \
# 6932   58   39   53   19   57     5  60+2  60+2  60+2  54+0  57+0  57+0  57+0
#
#         rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm  \
# 6932  54+0  53+2  53+2  53+2  52+2  46+2  46+2  46+2  52+2  37+2  36+2  36+2
#
#        rdm   rwb    lb   lcb    cb   rcb    rb    gk gender    h_cm  \
# 6932  36+2  37+2  36+2  34+2  34+2  34+2  36+2  17+2   Male  187.96
#
#            w_kg  w_f  sinister  a_wr  d_wr  pot_minus_ova
# 6932  73.029121    3         0     2     2              7

# %% [markdown]
# [Presentation](https://docs.google.com/presentation/d/1Td9rJDfuB_epbsVk1nrdaiT-oH_MAjnKdBoWULncyT0/edit#slide=id.gc6f9e470d_0_126)

# %% [markdown]
# ## 00. Coding Best Practices

# %%
# Basic Libraries
import os
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Machine Learning
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet # Lasso, Ridge, ElasticNet are tests to minimize LinearRegression overfitting
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Settings
warnings.filterwarnings('ignore') 
pd.set_option('display.max_columns', None)

# %%
# Basic functions
def data_info(): # improved data.info()
    print(f"The DataFrame shape is {data.shape}.")
    print()
    print("The DataFrame data types are:")
    print(data.dtypes.value_counts().tolist())
    print(data.dtypes.value_counts().index.tolist())
    print()
    print("DataFrame random row sample and full columns:")
    return data.sample(5)

def clean_columns(): # Standardizes the column name, returns the columns
    data_copy.columns = [i.lower().replace(' ', '_') for i in data_copy.columns]
    return data_copy.sample(0)
       
# Specific functions for this dataset
def convert_value(value): # function to convert value to unified format
    try:
        if isinstance(value, float):
            return value
        elif value.endswith('K'):
            return float(value[1:-1]) * 1000
        elif value.endswith('M'):
            return float(value[1:-1]) * 1000000
        else:
            return float(value)
    except ValueError:
        return None

# %% [markdown]
# ## 01 - Getting the Data

# %%
file_path = os.path.join("C:/Users/apisi/01. IronData/01. GitHub/01. iron-activity/project-mbappe", "fifa21_male2.csv")
data = pd.read_csv(file_path)
data_info()
# Out:
# The DataFrame shape is (17125, 107).
#
# The DataFrame data types are:
# [52, 45, 10]
# [dtype('O'), dtype('int64'), dtype('float64')]
#
# DataFrame random row sample and full columns:
#            ID        Name  Age  OVA    Nationality              Club  BOV  \
# 2942   193331   K. Darlow   29   73        England  Newcastle United   73
# 3414   198831    Vinícius   22   70         Brazil         Adanaspor   71
# 11299  239125  E. Botheim   20   60         Norway    Stabæk Fotball   62
# 5523   211672     T. Boyd   25   74  United States       Beşiktaş JK   75
# 2353   189110   P. Hanlon   30   66       Scotland         Hibernian   66
#
#         BP  Position                                       Player Photo  \
# 2942    GK        GK  https://cdn.sofifa.com/players/193/331/20_120.png
# 3414    RW  ST LW LM  https://cdn.sofifa.com/players/198/831/17_120.png
# 11299   ST        ST  https://cdn.sofifa.com/players/239/125/20_120.png
# 5523   CAM     RM LM  https://cdn.sofifa.com/players/211/672/20_120.png
# 2353    CB        CB  https://cdn.sofifa.com/players/189/110/20_120.png
#
#                                               Club Logo  \
# 2942       https://cdn.sofifa.com/teams/13/light_60.png
# 3414   https://cdn.sofifa.com/teams/110401/light_60.png
# 11299     https://cdn.sofifa.com/teams/917/light_60.png
# 5523      https://cdn.sofifa.com/teams/327/light_60.png
# 2353       https://cdn.sofifa.com/teams/81/light_60.png
#
#                                     Flag Photo  POT  \
# 2942   https://cdn.sofifa.com/flags/gb-eng.png   75
# 3414       https://cdn.sofifa.com/flags/br.png   75
# 11299      https://cdn.sofifa.com/flags/no.png   75
# 5523       https://cdn.sofifa.com/flags/us.png   77
# 2353   https://cdn.sofifa.com/flags/gb-sct.png   66
#
#                            Team & Contract Height  Weight   foot  Growth  \
# 2942          Newcastle United 2014 ~ 2025   6'3"  172lbs  Right       2
# 3414                 Adanaspor 2017 ~ 2018  5'11"  159lbs  Right       5
# 11299  Stabæk Fotball Dec 31, 2020 On Loan  5'11"  154lbs  Right      15
# 5523               Beşiktaş JK 2019 ~ 2023  5'11"  146lbs  Right       3
# 2353                 Hibernian 2008 ~ 2022   6'1"  154lbs   Left       0
#
#              Joined Loan Date End  Value  Wage Release Clause  \
# 2942    Aug 4, 2014           NaN  €3.4M  €24K          €6.7M
# 3414   Jan 10, 2017           NaN  €1.8M  €15K             €0
# 11299  Jul 18, 2016  Dec 31, 2020  €450K  €700             €0
# 5523   Jul 16, 2019           NaN    €7M  €47K         €14.5M
# 2353    Jan 1, 2008           NaN  €525K   €3K          €919K
#
#                    Contract  Attacking  Crossing  Finishing  Heading Accuracy  \
# 2942            2014 ~ 2025         85        12         14                12
# 3414            2017 ~ 2018        324        66         72                51
# 11299  Dec 31, 2020 On Loan        241        32         62                59
# 5523            2019 ~ 2023        334        69         74                44
# 2353            2008 ~ 2022        221        55         28                66
#
#        Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  \
# 2942              32     15.0    104         12   19.0           16
# 3414              68     67.0    312         72   50.0           59
# 11299             46     42.0    214         58   37.0           30
# 5523              72     75.0    337         76   74.0           70
# 2353              59     13.0    240         52   59.0           12
#
#        Long Passing  Ball Control  Movement  Acceleration  Sprint Speed  \
# 2942             28            29       303            59            52
# 3414             58            73       365            76            77
# 11299            29            60       324            62            67
# 5523             44            73       420            86            84
# 2353             58            59       318            67            54
#
#        Agility  Reactions  Balance  Power  Shot Power  Jumping  Stamina  \
# 2942      63.0         65     64.0    228          48     67.0       44
# 3414      74.0         72     66.0    336          73     64.0       72
# 11299     67.0         59     69.0    319          62     62.0       72
# 5523      87.0         77     86.0    336          79     59.0       70
# 2353      71.0         62     64.0    314          53     82.0       80
#
#        Strength  Long Shots  Mentality  Aggression  Interceptions  \
# 2942         58          11        112          13           26.0
# 3414         60          67        272          51           22.0
# 11299        62          61        238          34           31.0
# 5523         63          65        283          63           12.0
# 2353         77          22        247          68           64.0
#
#        Positioning  Vision  Penalties  Composure  Defending  Marking  \
# 2942          18.0    36.0         19       53.0         38       15
# 3414          68.0    59.0         72       61.0         69       26
# 11299         62.0    51.0         60       57.0         58       29
# 5523          75.0    68.0         65       64.0         46       20
# 2353          23.0    52.0         40       61.0        197       63
#
#        Standing Tackle  Sliding Tackle  Goalkeeping  GK Diving  GK Handling  \
# 2942                11            12.0          356         75           70
# 3414                21            22.0           51         12            9
# 11299               12            17.0           49          9           10
# 5523                14            12.0           50          8            7
# 2353                68            66.0           51         15           10
#
#        GK Kicking  GK Positioning  GK Reflexes  Total Stats  Base Stats  W/F  \
# 2942           64              71           76         1226         411  2 ★
# 3414            8               7           15         1729         370  3 ★
# 11299          13              12            5         1443         311  3 ★
# 5523           14              14            7         1806         384  4 ★
# 2353            6              10           10         1588         343  3 ★
#
#        SM     A/W     D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST  \
# 2942   1★  Medium  Medium  1 ★   75   70   64   76   55   71   35  30+2  30+2
# 3414   3★  Medium     Low  1 ★   77   71   63   72   26   61    3  69+1  69+1
# 11299  3★  Medium  Medium  1 ★   65   61   40   60   26   59    5  60+2  60+2
# 5523   3★  Medium  Medium  1 ★   85   73   66   77   18   65   52  72+2  72+2
# 2353   2★  Medium  Medium  1 ★   60   31   54   57   65   76    4  48+2  48+2
#
#          RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 2942   30+2  29+0  30+0  30+0  30+0  29+0  31+2  31+2  31+2  30+2  30+2  30+2
# 3414   69+1  71+0  70+0  70+0  70+0  71+0  69+1  69+1  69+1  70+1  62+1  62+1
# 11299  60+2  56+0  59+0  59+0  59+0  56+0  56+2  56+2  56+2  55+2  49+2  49+2
# 5523   72+2  75+0  74+0  74+0  74+0  75+0  73+2  73+2  73+2  73+2  63+2  63+2
# 2353   48+2  50+0  48+0  48+0  48+0  50+0  51+2  51+2  51+2  54+2  55+2  55+2
#
#         RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 2942   30+2  30+2  29+2  29+2  29+2  29+2  29+2  28+2  26+2  26+2  26+2  28+2
# 3414   62+1  70+1  53+1  48+1  48+1  48+1  53+1  49+1  40+1  40+1  40+1  49+1
# 11299  49+2  55+2  43+2  39+2  39+2  39+2  43+2  41+2  37+2  37+2  37+2  41+2
# 5523   63+2  73+2  51+2  46+2  46+2  46+2  51+2  46+2  37+2  37+2  37+2  46+2
# 2353   55+2  54+2  63+2  64+2  64+2  64+2  63+2  64+2  66+0  66+0  66+0  64+2
#
#          GK Gender
# 2942   72+2   Male
# 3414   17+1   Male
# 11299  15+2   Male
# 5523   17+2   Male
# 2353   17+2   Male

# %% [markdown]
# _____________
# <div class="alert alert-block alert-info">
#
# **First impression:**
#
# The following dataset is a collection of **one-year** 17.125 player information distributed among 107 different columns. The majority of our data types are mostly **numericals** (52 object / 45 integers / 10 floats).
#
# Our **project goal** is to identify players who have the potential to become **the next Mbappé**. After reading the [documentation](https://www.kaggle.com/datasets/ekrembayar/fifa-21-complete-player-dataset?select=fifa21_male2.csv) we decide to proceed with the following **strategy**:
#
# 1. The **target** of our dataset will be `OVA` (overall score), which is a summary of a player's performance and potential.
# 1. The majority of the data types are **numericals**, so we will work with that.
# 3. Through **Exploratory Data Analysis** we will identify the features that contribute to this prediction.
# _____________
# In previous versions, we removed some numerical features realted to player-potential. For this one, we will keep all features related to player attributes.
#
# Also in previous versions, we converted features like `Value`, `international_reputation`, `weak_feet` and `Release_clause`; we will not use them this time, since we don't want to predict the player market value.
#
# Lastly, features such as `'height'`, `'weight'`, etc., will be converted to the metric system by removing quotation symbols or lbs.
# </div>

# %% [markdown]
# ## 02 - Cleaning the Data

# %%
data_copy = data.copy() # as best practices, we do first a copy of our dataframe

# %%
clean_columns() # Standardizes the column name from data_copy
# Out:
# Empty DataFrame
# Columns: [id, name, age, ova, nationality, club, bov, bp, position, player_photo, club_logo, flag_photo, pot, team_&_contract, height, weight, foot, growth, joined, loan_date_end, value, wage, release_clause, contract, attacking, crossing, finishing, heading_accuracy, short_passing, volleys, skill, dribbling, curve, fk_accuracy, long_passing, ball_control, movement, acceleration, sprint_speed, agility, reactions, balance, power, shot_power, jumping, stamina, strength, long_shots, mentality, aggression, interceptions, positioning, vision, penalties, composure, defending, marking, standing_tackle, sliding_tackle, goalkeeping, gk_diving, gk_handling, gk_kicking, gk_positioning, gk_reflexes, total_stats, base_stats, w/f, sm, a/w, d/w, ir, pac, sho, pas, dri, def, phy, hits, ls, st, rs, lw, lf, cf, rf, rw, lam, cam, ram, lm, lcm, cm, rcm, rm, lwb, ldm, cdm, rdm, rwb, ...]
# Index: []

# %% [markdown]
# ### Encoding
# <div class="alert alert-block alert-warning">
#
# * To easily **clean** it, we will split the dataset to get all numericals.
# * Firstly, we need to encode some columns considered as **categoricals** that are actually **numericals**
# * e.g: `height`, `weight`, etc.
# </div>

# %%
# Applying lambda to:

# Convert height data from feet and inches to centimeters
data_copy['h_cm'] = data_copy['height'].apply(lambda x: int(x.split("'")[0])*30.48 + int(x.split("'")[1].replace('"', ''))*2.54)

# Convert weight data from pounds to kilograms
data_copy['w_kg'] = data_copy['weight'].apply(lambda x: int(x[:-3]) / 2.2046)

# Modify cells with 'K' character, leave others unchanged, turn it to integer
data_copy['hits'] = data_copy['hits'].apply(lambda x: float(x.replace('K','')) * 1000 if isinstance(x, str) and 'K' in x else x).astype(int)

# skilled_moves
data_copy['sm'] = data_copy['sm'].apply(lambda x: int(x[0]) if isinstance(x, str) else x)

# Visualizing the changes
data_encoded = data_copy[['h_cm', 'w_kg', 'hits', 'sm']]
data_encoded.head(5)
# Out:
#      h_cm       w_kg  hits  sm
# 0  182.88  82.101061     4   2
# 1  177.80  64.864374     4   3
# 2  175.26  73.029121    11   4
# 3  180.34  74.843509     3   1
# 4  170.18  68.039554   149   4

# %% [markdown]
# ### Further Encoding

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# * `a/w` stands for Attacking Work Rate
# * `d/w` stands for Defensive Work Rate
#
# **AKA.** Tendency to a player towards attack or defense.
# </div>

# %%
data_f_encoding = data_copy[['a/w', 'd/w']]
data_f_encoding.head(5)
# Out:
#       a/w     d/w
# 0  Medium    High
# 1  Medium  Medium
# 2  Medium     Low
# 3     NaN     NaN
# 4    High  Medium

# %%
# Initialize the LabelEncoder object from sklearn
le = LabelEncoder()

# Fit and transform the data frame column
data_copy['a_wr'] = le.fit_transform(data_copy['a/w'])
data_copy['d_wr'] = le.fit_transform(data_copy['d/w'])

# Visualizing the changes
data_encoded_f = data_copy[['a_wr', 'd_wr']]
data_comparision_2 = pd.concat([data_f_encoding, data_encoded_f], axis=1)
data_comparision_2.head(5)
# Out:
#       a/w     d/w  a_wr  d_wr
# 0  Medium    High     2     0
# 1  Medium  Medium     2     2
# 2  Medium     Low     2     1
# 3     NaN     NaN     3     3
# 4    High  Medium     0     2

# %% [markdown]
# ### Selecting numericals / Dealing with Null values

# %%
# Create a new dataframe with only the numerical columns using select_dtypes
X_N = data_copy.select_dtypes(np.number).fillna(0) # we also deal with NaN values
X_N.head(10)
# Out:
#     id  age  ova  bov  pot  growth  attacking  crossing  finishing  \
# 0    2   33   69   71   69       0        313        75         50
# 1   16   37   71   70   71       0        337        68         64
# 2   27   33   71   71   71       0        337        80         64
# 3   36   36   68   70   82      14        264        54         70
# 4   41   36   81   82   81       0        367        75         69
# 5   61   27   66   66   70       4        271        61         53
# 6   80   38   77   77   77       0        342        80         66
# 7  241   39   78   78   78       0        380        90         70
# 8  244   35   76   78   82       6        304        72         31
# 9  246   37   80   82   80       0        394        83         65
#
#    heading_accuracy  short_passing  volleys  skill  dribbling  curve  \
# 0                59             71     58.0    338         73   65.0
# 1                61             76     68.0    369         69   79.0
# 2                41             77     75.0    387         79   84.0
# 3                60             80      0.0    255         68    0.0
# 4                54             90     79.0    408         85   80.0
# 5                42             58     57.0    276         67   61.0
# 6                43             84     69.0    406         77   83.0
# 7                60             85     75.0    402         77   87.0
# 8                75             71     55.0    258         44   56.0
# 9                72             89     85.0    393         75   74.0
#
#    fk_accuracy  long_passing  ball_control  movement  acceleration  \
# 0           60            69            71       347            68
# 1           79            71            71       305            56
# 2           77            69            78       295            48
# 3           46            64            77       176            59
# 4           70            83            90       346            61
# 5           42            44            62       406            90
# 6           80            85            81       308            54
# 7           78            81            79       337            59
# 8           33            61            64       324            64
# 9           67            90            87       338            53
#
#    sprint_speed  agility  reactions  balance  power  shot_power  jumping  \
# 0            74     68.0         69     68.0    347          74     68.0
# 1            50     62.0         65     72.0    324          75     54.0
# 2            42     71.0         59     75.0    284          72     58.0
# 3            62      0.0         55      0.0    239          63      0.0
# 4            56     79.0         75     75.0    297          67     40.0
# 5            91     75.0         65     85.0    315          71     70.0
# 6            36     67.0         70     81.0    340          77     72.0
# 7            60     72.0         76     70.0    310          71     59.0
# 8            70     51.0         72     67.0    284          47     70.0
# 9            53     68.0         82     82.0    333          88     64.0
#
#    stamina  strength  long_shots  mentality  aggression  interceptions  \
# 0       69        68          68        320          72           69.0
# 1       64        60          71        362          71           71.0
# 2       29        56          69        317          69           39.0
# 3       51        66          59        271          59           70.0
# 4       58        62          70        370          58           70.0
# 5       64        61          49        256          63           26.0
# 6       51        64          76        384          87           62.0
# 7       48        61          71        358          60           47.0
# 8       65        74          28        319          87           85.0
# 9       34        63          84        417          87           79.0
#
#    positioning  vision  penalties  composure  defending  marking  \
# 0         63.0    66.0         50        0.0        208       70
# 1         72.0    73.0         75       79.0        153       70
# 2         69.0    74.0         66        0.0         99       35
# 3         72.0     0.0         70        0.0         75       34
# 4         78.0    93.0         71       89.0        181       68
# 5         63.0    58.0         46        0.0         79       22
# 6         65.0    85.0         85       80.0        190       65
# 7         78.0    83.0         90        0.0        120       26
# 8         45.0    70.0         32        0.0        242       78
# 9         83.0    91.0         77        0.0        143       58
#
#    standing_tackle  sliding_tackle  goalkeeping  gk_diving  gk_handling  \
# 0               69            69.0           56         14            5
# 1               43            40.0           56          9           12
# 2               34            30.0           51          9            6
# 3               41             0.0           68          5           21
# 4               57            56.0           45          6           13
# 5               26            31.0           46          8           13
# 6               65            60.0           47          7           11
# 7               43            51.0           32         10            5
# 8               81            83.0           43         12            9
# 9               49            36.0           47          7           12
#
#    gk_kicking  gk_positioning  gk_reflexes  total_stats  base_stats  sm  pac  \
# 0          15              10           12         1929         408   2   71
# 1          13              11           11         1906         385   3   53
# 2          13              16            7         1770         354   4   45
# 3          64              21           21         1348         369   1   61
# 4           6              13            7         2014         420   4   58
# 5           7               9            9         1649         360   3   91
# 6           7              14            8         2017         403   4   44
# 7           7               5            5         1939         392   3   60
# 8           5               6           11         1774         378   2   67
# 9           5              15            8         2065         415   3   53
#
#    sho  pas  dri  def  phy  hits    h_cm       w_kg  a_wr  d_wr
# 0   59   70   71   68   69     4  182.88  82.101061     2     0
# 1   69   73   69   58   63     4  177.80  64.864374     2     2
# 2   68   76   77   36   52    11  175.26  73.029121     2     1
# 3   66   66   69   47   60     3  180.34  74.843509     3     3
# 4   70   85   85   63   59   149  170.18  68.039554     0     2
# 5   56   56   67   27   63     7  172.72  73.936315     2     2
# 6   71   83   77   62   66     7  170.18  72.121927     2     2
# 7   72   85   77   41   57     9  177.80  71.214733     2     2
# 8   36   67   53   81   74     4  177.80  78.925882     3     3
# 9   76   87   79   59   61     7  170.18  71.214733     2     2

# %% [markdown]
# ### Dropping unnecesary features

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# From all features above, we will drop the following:
# * `id` it's just the player identifier.
# * `bov` after many attempts and previous versions, it always show high multicollinearity with `ova`, so we will drop it now.
# * Features related to **goalkeepers** will be also reduced: `goalkeeping`, `gk_diving`, `gk_handling`, `gk_kicking`, `gk_positioning`, and `gk_reflexes`
# * `base_stats` and `total_stats` are the sum of different stats. Also, same with `crossing`, `finishing`, etc., are the sum of `attacking`:
#     * Attacking = crossing, finishing, heading_accuracy, short_passing, volleys
#     * Skill = dribbling, curve, fk_accuracy, long_passing, ball_control
#     * Movement = acceleration, sprint_speed, agility, reactions, balance
#     * Power = shot_power, jumping, stamina, strength, long_shots
#     * Mentality = aggression, interceptions, positioning, vision, penalties, composure
#     * Defending = marking, standing_tackle, sliding_tackle
# </div>

# %%
X_N = X_N.drop(columns=['id', 'bov', 'base_stats', 'total_stats', 'goalkeeping', 'gk_diving', 'gk_positioning', 'gk_reflexes', 'gk_handling', 'gk_kicking'])

# %%
# Now, we will get a list of all column names to just quickly move the target at the end
data_headers = list(X_N.columns.values) # to get and check all column names
print("The Column Headers are :", data_headers)
# Out:
# The Column Headers are : ['age', 'ova', 'pot', 'growth', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'sm', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits', 'h_cm', 'w_kg', 'a_wr', 'd_wr']

# %%
# We simply move our target overall_scores to the right, for readibility and remove the rest of the columns that are summarized in other stats
X_N = X_N[['age', 'pot', 'growth', 'attacking', 'skill', 'movement', 'power', 'mentality', 'defending', 'sliding_tackle',
            'sm', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits', 'h_cm', 'w_kg', 'a_wr', 'd_wr', 'ova']]
X_N.shape
# Out:
# (17125, 23)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Now**, we have a cleaned dataset with `17.125` numerical player information in `23` distinct numerical features.
# </div>

# %%
X_N.sample(5)
# Out:
#        age  pot  growth  attacking  skill  movement  power  mentality  \
# 11045   21   75      11        190    183       285    255        221
# 4960    27   72       0        272    248       337    299        298
# 4300    28   68       0        334    355       342    358        307
# 12057   19   74      13        239    242       339    263        258
# 14317   22   75       7        292    295       349    332        308
#
#        defending  sliding_tackle  sm  pac  sho  pas  dri  def  phy  hits  \
# 11045        192            56.0   2   57   27   43   40   65   64     4
# 4960         225            75.0   2   67   45   57   62   72   66    10
# 4300         139            32.0   3   72   68   68   70   53   68     3
# 12057        177            57.0   2   70   44   54   56   58   53    15
# 14317        191            62.0   2   70   56   66   69   65   68    10
#
#          h_cm       w_kg  a_wr  d_wr  ova
# 11045  187.96  74.843509     2     2   64
# 4960   180.34  73.936315     1     2   72
# 4300   182.88  76.204300     2     1   68
# 12057  172.72  58.060419     2     2   61
# 14317  182.88  73.936315     0     0   68

# %% [markdown]
# ## 03 - Exploratory Data Analysis

# %%
# Looking at promising talents
data_copy['pot_minus_ova'] = data_copy['pot'] - data_copy['ova'] 

# Create a new DataFrame that contains only the rows with "difference" > 10 and age < 21
talents = data_copy[(data_copy['pot_minus_ova'] > 10) & (data_copy['age'] < 21)]
talents_sorted = talents.sort_values('pot_minus_ova', ascending=False)
talents_sorted.head(3)
# Out:
#            id          name  age  ova  nationality                  club  bov  \
# 16660  257793   R. Richards   16   54      England  West Bromwich Albion   55
# 17112  259074    A. Hajdari   17   53  Switzerland         FC Basel 1893   55
# 16812  258315  B. Arrey-Mbi   17   60      Germany     Bayern München II   62
#
#        bp position                                       player_photo  \
# 16660  LM   LM CAM  https://cdn.sofifa.com/players/257/793/20_120.png
# 17112  CB       CB  https://cdn.sofifa.com/players/259/074/20_120.png
# 16812  CB    CB LB  https://cdn.sofifa.com/players/258/315/20_120.png
#
#                                               club_logo  \
# 16660     https://cdn.sofifa.com/teams/109/light_60.png
# 17112     https://cdn.sofifa.com/teams/896/light_60.png
# 16812  https://cdn.sofifa.com/teams/110679/light_60.png
#
#                                     flag_photo  pot  \
# 16660  https://cdn.sofifa.com/flags/gb-eng.png   80
# 17112      https://cdn.sofifa.com/flags/ch.png   79
# 16812      https://cdn.sofifa.com/flags/de.png   86
#
#                         team_&_contract height  weight  foot  growth  \
# 16660  West Bromwich Albion 2020 ~ 2023  5'10"  150lbs  Left      26
# 17112         FC Basel 1893 2020 ~ 2024   6'2"  176lbs  Left      26
# 16812     Bayern München II 2020 ~ 2022   6'2"  168lbs  Left      26
#
#              joined loan_date_end  value  wage release_clause     contract  \
# 16660   Aug 4, 2020           NaN  €150K   €1K          €450K  2020 ~ 2023
# 17112  Sep 14, 2020           NaN  €120K  €500          €300K  2020 ~ 2024
# 16812   Jul 1, 2020           NaN  €425K  €500            €1M  2020 ~ 2022
#
#        attacking  crossing  finishing  heading_accuracy  short_passing  \
# 16660        220        52         40                37             50
# 17112        161        31         17                53             32
# 16812        204        34         25                59             56
#
#        volleys  skill  dribbling  curve  fk_accuracy  long_passing  \
# 16660     41.0    248         59   47.0           41            43
# 17112     28.0    134         22   30.0           29            25
# 16812     30.0    207         49   31.0           29            44
#
#        ball_control  movement  acceleration  sprint_speed  agility  reactions  \
# 16660            58       313            72            64     62.0         43
# 17112            28       262            58            61     45.0         48
# 16812            54       324            66            70     68.0         52
#
#        balance  power  shot_power  jumping  stamina  strength  long_shots  \
# 16660     72.0    251          53     51.0       54        45          48
# 17112     50.0    252          38     66.0       56        68          24
# 16812     68.0    273          38     78.0       62        71          24
#
#        mentality  aggression  interceptions  positioning  vision  penalties  \
# 16660        194          33           16.0         39.0    55.0         51
# 17112        195          51           53.0         28.0    27.0         36
# 16812        228          63           53.0         35.0    44.0         33
#
#        composure  defending  marking  standing_tackle  sliding_tackle  \
# 16660       48.0         84       22               29            33.0
# 17112       39.0        157       47               58            52.0
# 16812       56.0        180       55               64            61.0
#
#        goalkeeping  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 16660           43         10            8           8               8
# 17112           46         12            9           9              11
# 16812           50         13            9           8              12
#
#        gk_reflexes  total_stats  base_stats  w/f  sm     a/w     d/w   ir  \
# 16660            9         1353         293  3 ★   2  Medium  Medium  1 ★
# 17112            5         1207         259  3 ★   2     Low  Medium  1 ★
# 16812            8         1466         322  3 ★   2  Medium  Medium  1 ★
#
#        pac  sho  pas  dri  def  phy  hits    ls    st    rs    lw    lf    cf  \
# 16660   68   45   50   59   26   45    83  48+2  48+2  48+2  53+0  51+0  51+0
# 17112   60   25   30   29   53   62    37  36+2  36+2  36+2  32+0  32+0  32+0
# 16812   68   29   45   54   58   68   720  46+2  46+2  46+2  47+0  46+0  46+0
#
#          rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm  \
# 16660  51+0  53+0  52+2  52+2  52+2  53+2  47+2  47+2  47+2  53+2  43+2  38+2
# 17112  32+0  32+0  31+2  31+2  31+2  34+2  33+2  33+2  33+2  34+2  45+2  44+2
# 16812  46+0  47+0  48+2  48+2  48+2  49+2  49+2  49+2  49+2  49+2  55+2  56+2
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk gender    h_cm  \
# 16660  38+2  38+2  43+2  41+2  34+2  34+2  34+2  41+2  12+2   Male  177.80
# 17112  44+2  44+2  45+2  48+2  53+2  53+2  53+2  48+2  14+2   Male  187.96
# 16812  56+2  56+2  55+2  57+2  60+2  60+2  60+2  57+2  15+2   Male  187.96
#
#             w_kg  a_wr  d_wr  pot_minus_ova
# 16660  68.039554     2     2             26
# 17112  79.833076     1     2             26
# 16812  76.204300     2     2             26

# %%
# Looking at Overall Score Plaer with rating >80
mvps = data_copy[(data_copy['ova'] > 80)]

# Sort the MVPs
mvps_sorted = mvps.sort_values('ova', ascending=False)
mvps_sorted.head(5)
# Out:
#           id               name  age  ova nationality                 club  \
# 752   158023           L. Messi   33   93   Argentina         FC Barcelona
# 142    20801  Cristiano Ronaldo   35   92    Portugal             Juventus
# 2287  188545     R. Lewandowski   31   91      Poland    FC Bayern München
# 2650  190871          Neymar Jr   28   91      Brazil  Paris Saint-Germain
# 2871  192985       K. De Bruyne   29   91     Belgium      Manchester City
#
#       bov   bp  position                                       player_photo  \
# 752    93   RW  RW ST CF  https://cdn.sofifa.com/players/158/023/20_120.png
# 142    92   ST     ST LW  https://cdn.sofifa.com/players/020/801/20_120.png
# 2287   91   ST        ST  https://cdn.sofifa.com/players/188/545/20_120.png
# 2650   91   LW    LW CAM  https://cdn.sofifa.com/players/190/871/20_120.png
# 2871   91  CAM    CAM CM  https://cdn.sofifa.com/players/192/985/20_120.png
#
#                                           club_logo  \
# 752   https://cdn.sofifa.com/teams/241/light_60.png
# 142    https://cdn.sofifa.com/teams/45/light_60.png
# 2287   https://cdn.sofifa.com/teams/21/light_60.png
# 2650   https://cdn.sofifa.com/teams/73/light_60.png
# 2871   https://cdn.sofifa.com/teams/10/light_60.png
#
#                                flag_photo  pot  \
# 752   https://cdn.sofifa.com/flags/ar.png   93
# 142   https://cdn.sofifa.com/flags/pt.png   92
# 2287  https://cdn.sofifa.com/flags/pl.png   91
# 2650  https://cdn.sofifa.com/flags/br.png   91
# 2871  https://cdn.sofifa.com/flags/be.png   91
#
#                       team_&_contract height  weight   foot  growth  \
# 752          FC Barcelona 2004 ~ 2021   5'7"  159lbs   Left       0
# 142              Juventus 2018 ~ 2022   6'2"  183lbs  Right       0
# 2287    FC Bayern München 2014 ~ 2023   6'0"  176lbs  Right       0
# 2650  Paris Saint-Germain 2017 ~ 2022   5'9"  150lbs  Right       0
# 2871      Manchester City 2015 ~ 2023  5'11"  154lbs  Right       0
#
#             joined loan_date_end   value   wage release_clause     contract  \
# 752    Jul 1, 2004           NaN  €67.5M  €560K        €138.4M  2004 ~ 2021
# 142   Jul 10, 2018           NaN    €46M  €220K         €75.9M  2018 ~ 2022
# 2287   Jul 1, 2014           NaN    €80M  €240K          €132M  2014 ~ 2023
# 2650   Aug 3, 2017           NaN    €90M  €270K        €166.5M  2017 ~ 2022
# 2871  Aug 30, 2015           NaN    €87M  €370K          €161M  2015 ~ 2023
#
#       attacking  crossing  finishing  heading_accuracy  short_passing  \
# 752         429        85         95                70             91
# 142         437        84         95                90             82
# 2287        423        71         94                85             84
# 2650        408        85         87                62             87
# 2871        407        94         82                55             94
#
#       volleys  skill  dribbling  curve  fk_accuracy  long_passing  \
# 752      88.0    470         96   93.0           94            91
# 142      86.0    414         88   81.0           76            77
# 2287     89.0    407         85   79.0           85            70
# 2650     87.0    448         95   88.0           89            81
# 2871     82.0    441         88   85.0           83            93
#
#       ball_control  movement  acceleration  sprint_speed  agility  reactions  \
# 752             96       451            91            80     91.0         94
# 142             92       431            87            91     87.0         95
# 2287            88       407            77            78     77.0         93
# 2650            95       453            94            89     96.0         91
# 2871            92       398            77            76     78.0         91
#
#       balance  power  shot_power  jumping  stamina  strength  long_shots  \
# 752      95.0    389          86     68.0       72        69          94
# 142      71.0    444          94     95.0       84        78          93
# 2287     82.0    420          89     84.0       76        86          85
# 2650     83.0    357          80     62.0       81        50          84
# 2871     76.0    408          91     63.0       89        74          91
#
#       mentality  aggression  interceptions  positioning  vision  penalties  \
# 752         347          44           40.0         93.0    95.0         75
# 142         353          63           29.0         95.0    82.0         84
# 2287        391          81           49.0         94.0    79.0         88
# 2650        356          51           36.0         87.0    90.0         92
# 2871        408          76           66.0         88.0    94.0         84
#
#       composure  defending  marking  standing_tackle  sliding_tackle  \
# 752        96.0         91       32               35            24.0
# 142        95.0         84       28               32            24.0
# 2287       88.0         96       35               42            19.0
# 2650       93.0         94       35               30            29.0
# 2871       91.0        186       68               65            53.0
#
#       goalkeeping  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 752            54          6           11          15              14
# 142            58          7           11          15              14
# 2287           51         15            6          12               8
# 2650           59          9            9          15              15
# 2871           56         15           13           5              10
#
#       gk_reflexes  total_stats  base_stats  w/f  sm     a/w     d/w   ir  pac  \
# 752             8         2231         466  4 ★   4  Medium     Low  5 ★   85
# 142            11         2221         464  4 ★   5    High     Low  5 ★   89
# 2287           10         2195         457  4 ★   4    High  Medium  4 ★   78
# 2650           11         2175         451  5 ★   5    High  Medium  5 ★   91
# 2871           13         2304         485  5 ★   4    High    High  4 ★   76
#
#       sho  pas  dri  def  phy  hits    ls    st    rs    lw    lf    cf    rf  \
# 752    92   91   95   38   65   830  89+3  89+3  89+3  92+0  93+0  93+0  93+0
# 142    93   81   89   35   77   750  91+1  91+1  91+1  89+0  91+0  91+0  91+0
# 2287   91   78   85   43   82   487  89+2  89+2  89+2  85+0  87+0  87+0  87+0
# 2650   85   86   94   36   59   546  84+3  84+3  84+3  90+0  89+0  89+0  89+0
# 2871   86   93   88   64   78   406  83+3  83+3  83+3  88+0  88+0  88+0  88+0
#
#         rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm  \
# 752   92+0  93+0  93+0  93+0  91+2  87+3  87+3  87+3  91+2  66+3  65+3  65+3
# 142   89+0  88+3  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3
# 2287  85+0  85+3  85+3  85+3  83+3  79+3  79+3  79+3  83+3  64+3  65+3  65+3
# 2650  90+0  90+1  90+1  90+1  90+1  83+3  83+3  83+3  90+1  67+3  62+3  62+3
# 2871  88+0  89+2  89+2  89+2  89+2  89+2  89+2  89+2  89+2  79+3  80+3  80+3
#
#        rdm   rwb    lb   lcb    cb   rcb    rb    gk gender    h_cm  \
# 752   65+3  66+3  62+3  52+3  52+3  52+3  62+3  19+3   Male  170.18
# 142   61+3  65+3  61+3  54+3  54+3  54+3  61+3  20+3   Male  187.96
# 2287  65+3  64+3  61+3  60+3  60+3  60+3  61+3  19+3   Male  182.88
# 2650  62+3  67+3  62+3  49+3  49+3  49+3  62+3  20+3   Male  175.26
# 2871  80+3  79+3  75+3  69+3  69+3  69+3  75+3  21+3   Male  180.34
#
#            w_kg  a_wr  d_wr  pot_minus_ova
# 752   72.121927     2     1              0
# 142   83.008255     0     1              0
# 2287  79.833076     0     2              0
# 2650  68.039554     0     2              0
# 2871  69.853942     0     0              0

# %%
# create a dataframe with 'name' and 'value' columns
df = pd.DataFrame(data_copy, columns=['name', 'value'])

# select the rows for the six specific players you want to plot
players = ['K. Mbappé', 'Neymar Jr', 'K. De Bruyne', 'R. Richards', 'A. Hajdari','B. Arrey-Mbi']
df_players = df[df['name'].isin(players)]

# create a bar chart
plt.figure(figsize=(8,6))
bars = plt.bar(df_players['name'], df_players['value'])
plt.ylabel('Value in €100Mio')
plt.title('Comparison of MVPs and Talents')

# show the chart
plt.show()

# %%
# Group the data by country and count the number of players in each country
mvps_by_country = mvps.groupby('nationality')['name'].count().sort_values(ascending=False)

# Plot a bar chart of the top 10 countries with the most players
mvps_by_country.head(10).plot(kind='bar')

# Add labels and a title to the chart
plt.xlabel('Country')
plt.ylabel('Number of players')
plt.title('Top 10 countries with the most valuable players')

# Display the chart
plt.show()

# %%
# Group the data by country and count the number of players in each country
talents_by_country = talents.groupby('nationality')['name'].count().sort_values(ascending=False)

# Plot a bar chart of the top 10 countries with the most players
talents_by_country.head(10).plot(kind='bar')

# Add labels and a title to the chart
plt.xlabel('Country')
plt.ylabel('Number of players')
plt.title('Top 10 countries with the most promising talents')

# Display the chart
plt.show()

# %% [markdown]
# ## 04 - Processing Data

# %% [markdown]
# ### Dealing with outliers

# %%
X_N.shape
# Out:
# (17125, 23)

# %%
# Automatically removing outliers
for column in X_N:
    Q1 = X_N[column].quantile(0.25)
    Q3 = X_N[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    X_N = X_N[(X_N[column] >= lower_bound) & (X_N[column] <= upper_bound)]

# %%
# Visualizing the changes

fig, ax = plt.subplots(figsize=(30, 12))
sns.boxplot(data=X_N, orient="h", ax=ax, showfliers=True, whis=1.5)

# Set the x-axis label
ax.set_ylabel("Features")
# Set the title of the plot
ax.set_title("Features Outliers")
# Adjust the font size of the x-axis ticks
ax.tick_params(axis='x', labelsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ## !
# #### To check later...
# Dealing with specific outliers like `hits`.

# %% [markdown]
# ### Checking normal distributions

# %%
# set color palette
colors = ['#0072B2'] # blue

# plot normalized features in a grid
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20, 16)) # nrows to 5, ncols to 6 to plot our 26 features
for i, ax in enumerate(axes.flat):
    if i >= len(X_N.columns):
        break
    sns.histplot(X_N.iloc[:, i], ax=ax, color=colors[i % len(colors)], kde=True)
    sns.kdeplot(X_N.iloc[:, i], ax=ax, color='#999999', linewidth=2)
    ax.set_title(X_N.columns[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# The majority of our features seems to have a bell-shape curve, so we can use **MinMaxScaler** for normalization.

# %% [markdown]
# ### Dealing with multicollinearity

# %%
# Show Matrix
X_corr = round(X_N.corr(), 4)
X_corr
# Out:
#                    age     pot  growth  attacking   skill  movement   power  \
# age             1.0000 -0.2639 -0.8671     0.5067  0.4367    0.0772  0.5410
# pot            -0.2639  1.0000  0.3633     0.2182  0.2479    0.1618  0.1191
# growth         -0.8671  0.3633  1.0000    -0.5243 -0.4488   -0.1811 -0.5882
# attacking       0.5067  0.2182 -0.5243     1.0000  0.7966    0.3901  0.6867
# skill           0.4367  0.2479 -0.4488     0.7966  1.0000    0.4699  0.5322
# movement        0.0772  0.1618 -0.1811     0.3901  0.4699    1.0000  0.2157
# power           0.5410  0.1191 -0.5882     0.6867  0.5322    0.2157  1.0000
# mentality       0.5892  0.2154 -0.5728     0.6770  0.7129    0.2280  0.6736
# defending       0.2007  0.1370 -0.1897    -0.1898  0.0229   -0.1974  0.0712
# sliding_tackle  0.1589  0.1329 -0.1455    -0.2188 -0.0002   -0.1977  0.0296
# sm              0.2536  0.1680 -0.2843     0.5763  0.6195    0.5019  0.3138
# pac            -0.1179  0.1070 -0.0138     0.1761  0.1909    0.8535  0.0788
# sho             0.3326  0.1201 -0.3499     0.8755  0.6917    0.4017  0.6363
# pas             0.4673  0.2670 -0.4805     0.7585  0.9248    0.4180  0.5100
# dri             0.3223  0.3019 -0.3759     0.7701  0.8520    0.6889  0.4656
# def             0.2494  0.1420 -0.2369    -0.1449  0.0362   -0.2114  0.1272
# phy             0.4507  0.0516 -0.4862     0.1866  0.0600   -0.1860  0.6860
# hits           -0.0490  0.5146  0.0614     0.2404  0.2263    0.1751  0.1767
# h_cm            0.0451 -0.0099 -0.0403    -0.0901 -0.2767   -0.5853  0.1500
# w_kg            0.2108 -0.0347 -0.2073     0.0361 -0.1527   -0.4673  0.3037
# a_wr           -0.0961 -0.0568  0.1181    -0.2186 -0.1766   -0.2817 -0.1793
# d_wr           -0.1714 -0.0162  0.1541    -0.0602 -0.0304    0.0408 -0.1763
# ova             0.6327  0.4318 -0.6835     0.6785  0.6287    0.3021  0.6628
#
#                 mentality  defending  sliding_tackle      sm     pac     sho  \
# age                0.5892     0.2007          0.1589  0.2536 -0.1179  0.3326
# pot                0.2154     0.1370          0.1329  0.1680  0.1070  0.1201
# growth            -0.5728    -0.1897         -0.1455 -0.2843 -0.0138 -0.3499
# attacking          0.6770    -0.1898         -0.2188  0.5763  0.1761  0.8755
# skill              0.7129     0.0229         -0.0002  0.6195  0.1909  0.6917
# movement           0.2280    -0.1974         -0.1977  0.5019  0.8535  0.4017
# power              0.6736     0.0712          0.0296  0.3138  0.0788  0.6363
# mentality          1.0000     0.4004          0.3610  0.3607 -0.0365  0.4861
# defending          0.4004     1.0000          0.9804 -0.2366 -0.2798 -0.4751
# sliding_tackle     0.3610     0.9804          1.0000 -0.2491 -0.2696 -0.4969
# sm                 0.3607    -0.2366         -0.2491  1.0000  0.3324  0.5693
# pac               -0.0365    -0.2798         -0.2696  0.3324  1.0000  0.2363
# sho                0.4861    -0.4751         -0.4969  0.5693  0.2363  1.0000
# pas                0.7767     0.2027          0.1755  0.5393  0.1302  0.5648
# dri                0.5721    -0.1723         -0.1904  0.6824  0.4335  0.7210
# def                0.4466     0.9915          0.9602 -0.2302 -0.2994 -0.4421
# phy                0.5161     0.4677          0.4274 -0.0960 -0.1816  0.0010
# hits               0.2138     0.0680          0.0521  0.2017  0.1231  0.1672
# h_cm              -0.0452     0.1155          0.0982 -0.2579 -0.3706 -0.1434
# w_kg               0.0819     0.1223          0.0997 -0.1759 -0.3278 -0.0337
# a_wr              -0.1328     0.1003          0.1024 -0.2040 -0.2727 -0.2227
# d_wr              -0.1767    -0.1539         -0.1383  0.0249  0.0893 -0.0075
# ova                0.7234     0.2910          0.2449  0.4069  0.0972  0.4329
#
#                    pas     dri     def     phy    hits    h_cm    w_kg  \
# age             0.4673  0.3223  0.2494  0.4507 -0.0490  0.0451  0.2108
# pot             0.2670  0.3019  0.1420  0.0516  0.5146 -0.0099 -0.0347
# growth         -0.4805 -0.3759 -0.2369 -0.4862  0.0614 -0.0403 -0.2073
# attacking       0.7585  0.7701 -0.1449  0.1866  0.2404 -0.0901  0.0361
# skill           0.9248  0.8520  0.0362  0.0600  0.2263 -0.2767 -0.1527
# movement        0.4180  0.6889 -0.2114 -0.1860  0.1751 -0.5853 -0.4673
# power           0.5100  0.4656  0.1272  0.6860  0.1767  0.1500  0.3037
# mentality       0.7767  0.5721  0.4466  0.5161  0.2138 -0.0452  0.0819
# defending       0.2027 -0.1723  0.9915  0.4677  0.0680  0.1155  0.1223
# sliding_tackle  0.1755 -0.1904  0.9602  0.4274  0.0521  0.0982  0.0997
# sm              0.5393  0.6824 -0.2302 -0.0960  0.2017 -0.2579 -0.1759
# pac             0.1302  0.4335 -0.2994 -0.1816  0.1231 -0.3706 -0.3278
# sho             0.5648  0.7210 -0.4421  0.0010  0.1672 -0.1434 -0.0337
# pas             1.0000  0.7765  0.2171  0.1455  0.2294 -0.2616 -0.1361
# dri             0.7765  1.0000 -0.1614 -0.0434  0.2746 -0.3801 -0.2525
# def             0.2171 -0.1614  1.0000  0.5211  0.0770  0.1516  0.1624
# phy             0.1455 -0.0434  0.5211  1.0000  0.1015  0.4586  0.5634
# hits            0.2294  0.2746  0.0770  0.1015  1.0000  0.0274  0.0209
# h_cm           -0.2616 -0.3801  0.1516  0.4586  0.0274  1.0000  0.7236
# w_kg           -0.1361 -0.2525  0.1624  0.5634  0.0209  0.7236  1.0000
# a_wr           -0.1431 -0.2360  0.0985 -0.0341 -0.0953  0.1223  0.0813
# d_wr           -0.0667  0.0004 -0.1694 -0.2368 -0.0412 -0.0548 -0.1003
# ova             0.6744  0.6005  0.3406  0.5112  0.3438  0.0313  0.1735
#
#                   a_wr    d_wr     ova
# age            -0.0961 -0.1714  0.6327
# pot            -0.0568 -0.0162  0.4318
# growth          0.1181  0.1541 -0.6835
# attacking      -0.2186 -0.0602  0.6785
# skill          -0.1766 -0.0304  0.6287
# movement       -0.2817  0.0408  0.3021
# power          -0.1793 -0.1763  0.6628
# mentality      -0.1328 -0.1767  0.7234
# defending       0.1003 -0.1539  0.2910
# sliding_tackle  0.1024 -0.1383  0.2449
# sm             -0.2040  0.0249  0.4069
# pac            -0.2727  0.0893  0.0972
# sho            -0.2227 -0.0075  0.4329
# pas            -0.1431 -0.0667  0.6744
# dri            -0.2360  0.0004  0.6005
# def             0.0985 -0.1694  0.3406
# phy            -0.0341 -0.2368  0.5112
# hits           -0.0953 -0.0412  0.3438
# h_cm            0.1223 -0.0548  0.0313
# w_kg            0.0813 -0.1003  0.1735
# a_wr            1.0000  0.0750 -0.1589
# d_wr            0.0750  1.0000 -0.1620
# ova            -0.1589 -0.1620  1.0000

# %%
# Correlation Matrix-Heatmap Plot
mask = np.zeros_like(X_corr)
mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix
f, ax = plt.subplots(figsize=(25, 15))
sns.set(font_scale=1.5) # increase font size
ax = sns.heatmap(X_corr, mask=mask, annot=True, annot_kws={"size": 12}, linewidths=.5, cmap="coolwarm", fmt=".2f", ax=ax) # round to 2 decimal places
ax.set_title("Dealing with Multicollinearity", fontsize=20) # add title
plt.show()

# %% [markdown]
# We don't detect any multicollinearity, so we proceed.

# %% [markdown]
# ### X-Y Split

# %%
# We do X-Y SPLIT BEFORE normalizing. ~ Xisca. We don't want to normalize the target :) 
# We need to be careful about when we do the split.
Y = X_N['ova']
X = X_N.drop(['ova'], axis=1)

# %% [markdown]
# ### Normalizing the data

# %%
scaler = MinMaxScaler()
X_minmax = scaler.fit_transform(X)

# Making it a dataframe
X_minmax = pd.DataFrame(X_minmax, columns=X.columns)

# %%
# Checking again their distributions

# set color palette
colors = ['#0072B2'] # blue

# plot normalized features in a grid
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20, 16)) # nrows to 5, ncols to 6 to plot our 26 features
for i, ax in enumerate(axes.flat):
    if i >= len(X_minmax.columns):
        break
    sns.histplot(X_minmax.iloc[:, i], ax=ax, color=colors[i % len(colors)], kde=True)
    sns.kdeplot(X_minmax.iloc[:, i], ax=ax, color='#999999', linewidth=2)
    ax.set_title(X_minmax.columns[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 05 - Modeling

# %% [markdown]
# ### Train-Test Split

# %%
# We define train and test for X and Y
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) 

# test_size = We give 30% for testing and 70% for testing
# random_state = it'll improve the model to divide always the model in the same way

# %%
len(X) # Len before the test
# Out:
# 11964

# %%
len(X_test) # Len after testing 30% of X data
# Out:
# 3590

# %%
len(X_train) # Len after training 70% of X data
# Out:
# 8374

# %% [markdown]
# ### LinearRegression

# %%
# Settings
LR = LinearRegression() # We select the model

# Train data for the model
LR.fit(X_train, y_train)

# Predictions
predictions = LR.predict(X_test)

r2 = r2_score(y_test, predictions)
RMSE = mean_squared_error(y_test, predictions, squared=False)
MSE = mean_squared_error(y_test, predictions)
MAE = mean_absolute_error(y_test, predictions)

#Printing the results
print("R2 = ", round(r2, 4))
print("RMSE = ", round(RMSE, 4))
print("The value of the metric MSE is ", round(MSE, 4))
print("MAE = ", round(MAE, 4))
# Out:
# R2 =  1.0
# RMSE =  0.0
# The value of the metric MSE is  0.0
# MAE =  0.0

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Our model has a R-squared (`R2`) of `1.0`, which explains 100% of the variance of the data.
#
# Root Mean Squarred Error (`RMSE`), Mean Squarred Error `MSE` and Mean Absolute Error `MAE` are 0, meaning that the predicted values are close to the actual values.
#
# Previous results were:
# R2 =  1.0
# RMSE =  1.1837269792931977e-13
# The value of the metric MSE is  1.4012095615065982e-26
# MAE =  7.482272230109035e-14
#
# So this is a **slighly** improvement in terms of minimal error. But also... **too perfect** to be true!!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# The model might be overfitted. We will use `Lasso`, `Ridge` and `ElasticNet` from sklearn to improve our model -> [documentation](https://www.cienciadedatos.net/documentos/py14-ridge-lasso-elastic-net-python.html) ~ Ty, Xisca!!!
# </div>

# %% [markdown]
# ### Dealing with an overfitted model...

# %% [markdown]
# ### Lasso
# Lasso will shrink all values to 0, excluding non-relevant predictors.
#
# It starts with `1.0` or a `full penalty`.

# %%
# Settings
alpha = 1.0 
lasso = Lasso(alpha=alpha)

# Train data for the model
lasso.fit(X_train, y_train)

# Predictions
predictions_1 = lasso.predict(X_test)

r2_1 = r2_score(y_test, predictions_1)
RMSE_1 = mean_squared_error(y_test, predictions_1, squared=False)
MSE_1 = mean_squared_error(y_test, predictions_1)
MAE_1 = mean_absolute_error(y_test, predictions_1)

#Printing the results
print("R2 = ", round(r2_1, 4))
print("RMSE = ", round(RMSE_1, 4))
print("The value of the metric MSE is ", round(MSE_1, 4))
print("MAE = ", round(MAE_1, 4))
# Out:
# R2 =  0.9902
# RMSE =  0.5643
# The value of the metric MSE is  0.3184
# MAE =  0.4446

# %% [markdown]
# ### Ridge

# %%
# Settings
alpha = 1.0
ridge = Ridge(alpha=alpha)

# Train data for the model
ridge.fit(X_train, y_train)

# Predictions
predictions_2 = ridge.predict(X_test)

r2_2 = r2_score(y_test, predictions_2)
RMSE_2 = mean_squared_error(y_test, predictions_2, squared=False)
MSE_2 = mean_squared_error(y_test, predictions_2)
MAE_2 = mean_absolute_error(y_test, predictions_2)

#Printing the results
print("R2 = ", round(r2_2, 4))
print("RMSE = ", round(RMSE_2, 4))
print("The value of the metric MSE is ", round(MSE_2, 4))
print("MAE = ", round(MAE_2, 4))
# Out:
# R2 =  1.0
# RMSE =  0.0001
# The value of the metric MSE is  0.0
# MAE =  0.0001

# %% [markdown]
# ### ElasticNet

# %%
# Settings
alpha = 1.0
l1_ratio = 0.5
elasticnet = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)

# Train data for the model
elasticnet.fit(X_train, y_train)

# Predictions
predictions_3 = elasticnet.predict(X_test)

r2_3 = r2_score(y_test, predictions_3)
RMSE_3 = mean_squared_error(y_test, predictions_3, squared=False)
MSE_3 = mean_squared_error(y_test, predictions_3)
MAE_3 = mean_absolute_error(y_test, predictions_3)

#Printing the results
print("R2 = ", round(r2_3, 4))
print("RMSE = ", round(RMSE_3, 4))
print("The value of the metric MSE is ", round(MSE_3, 4))
print("MAE = ", round(MAE_3, 4))
# Out:
# R2 =  0.9908
# RMSE =  0.5464
# The value of the metric MSE is  0.2985
# MAE =  0.4291

# %% [markdown]
# <!-- HTML Code: Place this code in the document's body (between the 'body' tags) where the table should appear -->
# <table class="GeneratedTable">
#   <thead>
#     <tr>
#       <th>Results</th>
#       <th>LinearRegression</th>
#       <th>Lasso</th>
#       <th>Ridge</th>
#       <th>ElasticNet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>R2</b></td>
#       <td>1.0</td>
#       <td>0.9902</td>
#       <td>1.0</td>
#       <td>0.9908</td>
#     </tr>
#     <tr>
#       <td><b>RMSE</b></td>
#       <td>0.0</td>
#       <td>0.5643</td>
#       <td>0.0001</td>
#       <td>0.5464</td>
#     </tr>
#     <tr>
#       <td><b>MSE</b></td>
#       <td>0.0</td>
#       <td>0.3184</td>
#       <td>0.0</td>
#       <td>0.2985</td>
#     </tr>
#     <tr>
#       <td><b>MAE</b></td>
#       <td>0.0</td>
#       <td>0.4446</td>
#       <td>0.0001</td>
#       <td>0.4291</td>
#     </tr>
#   </tbody>
# </table>
#
# Of all <b>results</b>, ElasticNet provides the most realistic model (balanced between overfitting and underfitting).
# We will use this one !

# %% [markdown]
# ## 06 - Reporting

# %% [markdown]
# ### Presenting the results

# %%
# Dataframe for true, predicted and absolute difference values
results = pd.DataFrame()
results['true'] = y_test
results['pred'] = predictions_3
results['diff'] = results.apply(lambda x: abs(x['true'] - x['pred']), axis=1)

# Scale the true and predicted values to be between 0 and 1
results['true_scaled'] = (results['true'] - results['true'].min()) / (results['true'].max() - results['true'].min())
results['pred_scaled'] = (results['pred'] - results['pred'].min()) / (results['pred'].max() - results['pred'].min())

# %%
# Create the plot with regression line
sns.set_style('whitegrid')
sns.regplot(x='true_scaled', y='pred_scaled', data=results, color='black', scatter_kws={'s': 100, 'color': '#1f77b4', 'alpha': 0.5, 'edgecolor': 'w'})
plt.xlabel('True Values', fontsize=14, fontweight='bold', color='#34495e')
plt.ylabel('Predicted Values', fontsize=14, fontweight='bold', color='#34495e')
plt.title('True Values Vs Predictions', fontsize=16, fontweight='bold', color='#34495e')
plt.xticks(fontsize=12, color='#34495e')
plt.yticks(fontsize=12, color='#34495e')
plt.tight_layout()
plt.show()

# %% [markdown]
# ~ From Discord, import Sabina-savinness
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# So, I overdid. But learn through the process :D
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# [Old Presentation](https://docs.google.com/presentation/d/1Td9rJDfuB_epbsVk1nrdaiT-oH_MAjnKdBoWULncyT0/edit#slide=id.gc6f9e470d_0_126)

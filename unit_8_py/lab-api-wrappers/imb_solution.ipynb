# %% [markdown]
# ![logo_ironhack_blue 7](https://user-images.githubusercontent.com/23629340/40541063-a07a0a8a-601a-11e8-91b5-2f13e4e6b441.png)
#
# # Lab | API wrappers - Create your collection of songs & audio features
#
#
# #### Instructions
#
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# <h1 style="color: #00BFFF;">00 |</h1>

# %%
# 📚 Basic libraries
import pandas as pd # dataframe managment

# 🧩 New libraries
import spotipy # Spotify API for developers
from spotipy.oauth2 import SpotifyClientCredentials # Spotify user credentiials
import pprint # Makes dictionaries pretty to navigate when printed

# %% [markdown]
# <h1 style="color: #00BFFF;">01 | Data Extraction</h1>

# %% [markdown]
# <h3 style="color: #008080;">API acces</h3>

# %%
# Don't copy this, those are my credientials :P
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="d565de5f22d343be949f165e317b3448",
                                                           client_secret="9ec0e5075f784243b25dedcf5d91f149"))

# %% [markdown]
# <h3 style="color: #008080;">Playlist track</h3>

# %%
# Selecting the playlists; "Humans"
# This was a funny playlist. I asked 32 random friends for a 1 artist and 1 song in the first COVID lockdown
# The idea was to surprise them in my future wedding, making it sound there :D 
playlist = sp.user_playlist_tracks("spotify", "0Yf47MikpebEPxnZbAhEvn")
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0Yf47MikpebEPxnZbAhEvn/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-03-13T18:58:12Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/arattz'},
#                          'href': 'https://api.spotify.com/v1/users/arattz',
#                          'id': 'arattz',
#                          'type': 'user',
#                          'uri': 'spotify:user:arattz'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'compilation',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EBH204cwRkvAWknwTAjCQ'},
#                                              'href': 'https://api.spotify.com/v1/artists/5EBH204cwRkvAWknwTAjCQ',
#                                              'id': '5EBH204cwRkvAWknwTAjCQ',
#                                              'name': 'Marea',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5EBH204cwRkvAWknwTAjCQ'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'ET',
#                                                       'FI',
#                                                       'FJ',
#                                                       'FM',
#                                                       'FR',
#                                                       'GA',
#                                                       'GB',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GR',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HR',
#                                                       'HT',
#                                                       'HU',
#                                                       'ID',
#                                                       'IE',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'IS',
#                                                       'IT',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LI',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LT',
#                                                       'LU',
#                                                       'LV',
#                                                       'LY',
#                                                       'MA',
#                                                       'MC',
#                                                       'MD',
#                                                       'ME',
#                                                       'MG',
#                                                       'MH',
#                                                       'MK',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MT',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3mfnHHROaUAzdzmTZHI1YQ'},
#                                 'href': 'https://api.spotify.com/v1/albums/3mfnHHROaUAzdzmTZHI1YQ',
#                                 'id': '3mfnHHROaUAzdzmTZHI1YQ',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273b7d326ddc488886674513bba',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02b7d326ddc488886674513bba',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851b7d326ddc488886674513bba',
#                                             'width': 64}],
#                                 'name': 'Coces al Aire 1997-2007',
#                                 'release_date': '2007-12-04',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 33,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3mfnHHROaUAzdzmTZHI1YQ'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EBH204cwRkvAWknwTAjCQ'},
#                                    'href': 'https://api.spotify.com/v1/artists/5EBH204cwRkvAWknwTAjCQ',
#                                    'id': '5EBH204cwRkvAWknwTAjCQ',
#                                    'name': 'Marea',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5EBH204cwRkvAWknwTAjCQ'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 337666,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'ES6110058604'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6ScI1xf3RszISXvLGmitY3'},
#                       'href': 'https://api.spotify.com/v1/tracks/6ScI1xf3RszISXvLGmitY3',
#                       'id': '6ScI1xf3RszISXvLGmitY3',
#                       'is_local': False,
#                       'name': 'Corazon de mimbre',
#                       'popularity': 59,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/7b69f1835b0c515ead0a8a946cfd64a4b34acd63?cid=d565de5f22d343be949f165e317b3448',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:6ScI1xf3RszISXvLGmitY3'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2020-03-13T18:58:44Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/arattz'},
#                          'href': 'https://api.spotify.com/v1/users/arattz',
#                          'id': 'arattz',
#                          'type': 'user',
#                          'uri': 'spotify:user:arattz'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gjAu1qr5C2grXeQFFOGeh'},
#                                              'href': 'https://api.spotify.com/v1/artists/7gjAu1qr5C2grXeQFFOGeh',
#                                              'id': '7gjAu1qr5C2grXeQFFOGeh',
#                                              'name': 'Passion Pit',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7gjAu1qr5C2grXeQFFOGeh'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'ET',
#                                                       'FI',
#                                                       'FJ',
#                                                       'FM',
#                                                       'FR',
#                                                       'GA',
#                                                       'GB',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GR',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HR',
#                                                       'HT',
#                                                       'HU',
#                                                       'ID',
#                                                       'IE',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'IS',
#                                                       'IT',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LI',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LT',
#                                                       'LU',
#                                                       'LV',
#                                                       'LY',
#                                                       'MA',
#                                                       'MC',
#                                                       'MD',
#                                                       'ME',
#                                                       'MG',
#                                                       'MH',
#                                                       'MK',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MT',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/14JU5SskmcyckE5I8PY6lv'},
#                                 'href': 'https://api.spotify.com/v1/albums/14JU5SskmcyckE5I8PY6lv',
#                                 'id': '14JU5SskmcyckE5I8PY6lv',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273f860547bc8ba0c59df4fe2c3',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02f860547bc8ba0c59df4fe2c3',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851f860547bc8ba0c59df4fe2c3',
#                                             'width': 64}],
#                                 'name': 'Gossamer',
#                                 'release_date': '2012-07-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:14JU5SskmcyckE5I8PY6lv'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gjAu1qr5C2grXeQFFOGeh'},
#                                    'href': 'https://api.spotify.com/v1/artists/7gjAu1qr5C2grXeQFFOGeh',
#                                    'id': '7gjAu1qr5C2grXeQFFOGeh',
#                                    'name': 'Passion Pit',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7gjAu1qr5C2grXeQFFOGeh'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 264493,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSM11202617'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4Sfa7hdVkqlM8UW5LsSY3F'},
#                       'href': 'https://api.spotify.com/v1/tracks/4Sfa7hdVkqlM8UW5LsSY3F',
#                       'id': '4Sfa7hdVkqlM8UW5LsSY3F',
#                       'is_local': False,
#                       'name': 'Take a Walk',
#                       'popularity': 70,
# ...
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1obI3635eoYwWYhGs2vEeP'},
#                                 'href': 'https://api.spotify.com/v1/albums/1obI3635eoYwWYhGs2vEeP',
#                                 'id': '1obI3635eoYwWYhGs2vEeP',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273794179deeade79ef08eabd94',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02794179deeade79ef08eabd94',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851794179deeade79ef08eabd94',
#                                             'width': 64}],
#                                 'name': 'Eye of the Storm',
#                                 'release_date': '2019-02-15',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1obI3635eoYwWYhGs2vEeP'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7k73EtZwoPs516ZxE72KsO'},
#                                    'href': 'https://api.spotify.com/v1/artists/7k73EtZwoPs516ZxE72KsO',
#                                    'id': '7k73EtZwoPs516ZxE72KsO',
#                                    'name': 'ONE OK ROCK',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7k73EtZwoPs516ZxE72KsO'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 200226,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USAT21812307'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6KEkXeBJIHTFifMp9HK8tc'},
#                       'href': 'https://api.spotify.com/v1/tracks/6KEkXeBJIHTFifMp9HK8tc',
#                       'id': '6KEkXeBJIHTFifMp9HK8tc',
#                       'is_local': False,
#                       'name': 'Letting Go',
#                       'popularity': 53,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/ded5074b454937e9232d2943c491ac686d9dedba?cid=d565de5f22d343be949f165e317b3448',
#                       'track': True,
#                       'track_number': 8,
#                       'type': 'track',
#                       'uri': 'spotify:track:6KEkXeBJIHTFifMp9HK8tc'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 32}

# %% [markdown]
# <h3 style="color: #008080;">Getting artists from the playlist</h3>

# %%
artists = []
for i in range(len(playlist["items"])):
    artist = playlist["items"][i]["track"]["artists"][0]["name"]
    if artist not in artists:
        artists.append(artist)
artists
# Out:
# ['Marea',
#  'Passion Pit',
#  'Fleetwood Mac',
#  'Love of Lesbian',
#  'Solar Fake',
#  'Matt Simons',
#  'Qntal',
#  'Alice Cooper',
#  'Matisyahu',
#  'RAC',
#  'Nickelback',
#  'Franz Liszt',
#  'Rammstein',
#  'Red Hot Chili Peppers',
#  'Backstreet Boys',
#  'Radiohead',
#  'Whitesnake',
#  'Heroes Del Silencio',
#  'The Sound',
#  'Shawn Mendes',
#  'Patrick Cassidy',
#  'Fuel Fandango',
#  'Eluveitie',
#  'Michael Jackson',
#  'Fools Garden',
#  'The Dø',
#  'ZOO',
#  'Glen Hansard',
#  'Road Ramos',
#  'Robin Schulz',
#  'Babi',
#  'ONE OK ROCK']

# %% [markdown]
# <h3 style="color: #008080;">Getting all albums for each artist</h3>

# %%
albums = []
for i in range(len(playlist["items"])):
    album = playlist["items"][i]["track"]["album"]["name"]
    if album not in albums:
        albums.append(album)
albums
# Out:
# ['Coces al Aire 1997-2007',
#  'Gossamer',
#  'Tango In the Night (Deluxe Edition)',
#  'Manifiesto delirista',
#  'You Win. Who Cares?',
#  'After The Landslide (Remix)',
#  'VI - Translucida',
#  'Trash',
#  'Spark Seeker',
#  'Strangers',
#  'Here and Now (Audio Only Version)',
#  'Valentina Lisitsa Plays Liszt',
#  'Liebe ist für alle da (Special Edition)',
#  'Californication (Deluxe Edition)',
#  'Millennium',
#  'In Rainbows',
#  'Whitesnake (2018 Remaster)',
#  'El Espíritu Del Vino- Edición Especial',
#  'Jeopardy',
#  'Lost In Japan (Remix)',
#  'Hannibal - Original Motion Picture Soundtrack',
#  'Origen',
#  'Slania',
#  'Thriller 25 Super Deluxe Edition',
#  'Dish Of The Day',
#  'Shake, Shook, Shaken',
#  'Tempestes Vénen del Sud',
#  'Music From The Motion Picture Once',
#  '¿Qué sueñan los perros?',
#  'Sugar',
#  'Colegas',
#  'Eye of the Storm']

# %% [markdown]
# <h3 style="color: #008080;">Getting all songs from the playlist</h3>

# %%
tracks_title = []
for i in range(0,len(playlist["items"])):
    title = playlist["items"][i]["track"]["name"]
    tracks_title.append(title)

tracks_title
# Out:
# ['Corazon de mimbre',
#  'Take a Walk',
#  'Everywhere - 2017 Remaster',
#  'Manifiesto delirista',
#  'A Bullet Left for You',
#  'After The Landslide - Remix',
#  'Passacaglia',
#  'Poison',
#  'Live Like A Warrior',
#  'Let Go',
#  'Trying Not to Love You',
#  'Hungarian Rhapsody No. 12 in C sharp minor, S.244',
#  'Liebe ist für alle da',
#  'Otherside',
#  'I Want It That Way',
#  'Bodysnatchers',
#  'Is This Love - 2018 Remaster',
#  'La sirena varada',
#  "I Can't Escape Myself",
#  'Lost In Japan - Remix',
#  'Vide Cor Meum',
#  'Mi danza (feat. Dani de Morón)',
#  'Inis Mona',
#  'Billie Jean',
#  'Lemon Tree',
#  'Despair, Hangover & Ecstasy',
#  'Estiu',
#  'Falling Slowly',
#  'El Día Que Quieras',
#  'Sugar (feat. Francesco Yates)',
#  'Colegas',
#  'Letting Go']

# %% [markdown]
# <h3 style="color: #008080;">Getting song features from the playlist</h3>

# %%
tracks = playlist['items']

while playlist['next']:
    playlist = sp.next(playlist)
    tracks.extend(playlist['items'])

track_ids = [track['track']['id'] for track in tracks]

# %% [markdown]
# <h1 style="color: #00BFFF;">02 | Data Wrangling</h1>

# %%
features = sp.audio_features(track_ids[:100]) # getting features for each track
features_df = pd.DataFrame(features) # making it a df
features_df.head(5)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.521   0.928    9    -3.548     0       0.0837      0.023500
# 1         0.566   0.755   11    -5.526     1       0.0368      0.033800
# 2         0.730   0.487    4   -10.991     1       0.0303      0.258000
# 3         0.620   0.785    0    -6.320     1       0.0328      0.374000
# 4         0.633   0.831    9    -5.943     1       0.0283      0.000675
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00000    0.0961    0.323   90.555  audio_features
# 1           0.00000    0.3150    0.445  101.006  audio_features
# 2           0.01000    0.0852    0.731  114.965  audio_features
# 3           0.00001    0.0932    0.395  110.032  audio_features
# 4           0.00771    0.2800    0.445  136.016  audio_features
#
#                        id                                   uri  \
# 0  6ScI1xf3RszISXvLGmitY3  spotify:track:6ScI1xf3RszISXvLGmitY3
# 1  4Sfa7hdVkqlM8UW5LsSY3F  spotify:track:4Sfa7hdVkqlM8UW5LsSY3F
# 2  254bXAqt3zP6P50BdQvEsq  spotify:track:254bXAqt3zP6P50BdQvEsq
# 3  7A5yQ2gcJ3FA1wh5MNnibS  spotify:track:7A5yQ2gcJ3FA1wh5MNnibS
# 4  4zV7p7ldp1KpTKuCeVbOex  spotify:track:4zV7p7ldp1KpTKuCeVbOex
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6ScI1xf3RszI...
# 1  https://api.spotify.com/v1/tracks/4Sfa7hdVkqlM...
# 2  https://api.spotify.com/v1/tracks/254bXAqt3zP6...
# 3  https://api.spotify.com/v1/tracks/7A5yQ2gcJ3FA...
# 4  https://api.spotify.com/v1/tracks/4zV7p7ldp1Kp...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6ScI...       337666
# 1  https://api.spotify.com/v1/audio-analysis/4Sfa...       264493
# 2  https://api.spotify.com/v1/audio-analysis/254b...       226653
# 3  https://api.spotify.com/v1/audio-analysis/7A5y...       333413
# 4  https://api.spotify.com/v1/audio-analysis/4zV7...       329160
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
features_df = features_df.drop(["type", "id", "uri", "track_href", "analysis_url", "duration_ms", "time_signature"], axis=1) # dropping some ugly columns

# %%
features_df.head(5)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.521   0.928    9    -3.548     0       0.0837      0.023500
# 1         0.566   0.755   11    -5.526     1       0.0368      0.033800
# 2         0.730   0.487    4   -10.991     1       0.0303      0.258000
# 3         0.620   0.785    0    -6.320     1       0.0328      0.374000
# 4         0.633   0.831    9    -5.943     1       0.0283      0.000675
#
#    instrumentalness  liveness  valence    tempo
# 0           0.00000    0.0961    0.323   90.555
# 1           0.00000    0.3150    0.445  101.006
# 2           0.01000    0.0852    0.731  114.965
# 3           0.00001    0.0932    0.395  110.032
# 4           0.00771    0.2800    0.445  136.016

# %% [markdown]
# <h3 style="color: #008080;">Dictionaries rule</h3>

# %%
# Now, we will make a dictionary with our lists, assigning the future column name as key
ids = {
    'artist': artists,
    'album': albums,
    'song': tracks_title,
}

ids = pd.DataFrame(ids)

# %% [markdown]
# <h1 style="color: #00BFFF;">03 | Reporting</h1>

# %% [markdown]
# <h3 style="color: #008080;">Pandas rule the world -> making it a dataframe</h3>

# %%
df = pd.concat([ids, features_df], axis=1)

# %%
df.head(5)
# Out:
#             artist                                album  \
# 0            Marea              Coces al Aire 1997-2007
# 1      Passion Pit                             Gossamer
# 2    Fleetwood Mac  Tango In the Night (Deluxe Edition)
# 3  Love of Lesbian                 Manifiesto delirista
# 4       Solar Fake                  You Win. Who Cares?
#
#                          song  danceability  energy  key  loudness  mode  \
# 0           Corazon de mimbre         0.521   0.928    9    -3.548     0
# 1                 Take a Walk         0.566   0.755   11    -5.526     1
# 2  Everywhere - 2017 Remaster         0.730   0.487    4   -10.991     1
# 3        Manifiesto delirista         0.620   0.785    0    -6.320     1
# 4       A Bullet Left for You         0.633   0.831    9    -5.943     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0       0.0837      0.023500           0.00000    0.0961    0.323   90.555
# 1       0.0368      0.033800           0.00000    0.3150    0.445  101.006
# 2       0.0303      0.258000           0.01000    0.0852    0.731  114.965
# 3       0.0328      0.374000           0.00001    0.0932    0.395  110.032
# 4       0.0283      0.000675           0.00771    0.2800    0.445  136.016

# %%
df.to_csv('playlist.csv', index=False)

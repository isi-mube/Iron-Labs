# %% [markdown]
# ![logo_ironhack_blue 7](https://user-images.githubusercontent.com/23629340/40541063-a07a0a8a-601a-11e8-91b5-2f13e4e6b441.png)

# %% [markdown]
# <h1 style="color: #00BFFF;">00 | Getting started with Tableau</h1>

# %% [markdown]
# Refer to the `files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv` dataset.

# %%
# 📚 Basic libraries
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns

# ⚙️ Settings
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
def snake_columns(data): # snake_case columns
    data.columns = [column.lower().replace(' ', '_') for column in data.columns]
    return data.sample(0)

# %% [markdown]
# <h3 style="color: #008080;">1. Load the dataset into a notebook.
# </h3>

# %%
data = pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")
snake_columns(data)
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size]
# Index: []

# %% [markdown]
# <h3 style="color: #008080;">2. Create a barplot of the number of customers per <b>Gender</b>.</h3>

# %%
data['gender'].value_counts().plot(kind='bar', xlabel='Gender', ylabel='number_of_customers', rot=0)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='number_of_customers'>

# %% [markdown]
# <h3 style="color: #008080;">3. Create a barplot of the number of customers per <b>EmploymentStatus</b> and <b>Gender</b>.
# </h3>

# %%
# Nara's idea with crosstab! I forgot how to plot I think...
crosstab = pd.crosstab(data.employmentstatus, data.gender)

# Create bar plot
plot = crosstab.plot.bar(rot=0, color=['#800080', '#FFB347'])

# Customize plot
plt.title('Gender Distribution by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Count')

# Show plot
plt.show()

# %% [markdown]
# <h3 style="color: #008080;">4. Identify <b>Measurements</b> and <b>Dimensions</b>. Are they the same as the ones in your Pandas dataframe? Modify accordingly.
# </h3>

# %%
data.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %% [markdown]
# <h3 style="color: #008080;">5. Save as unit-4-lab.tbwx.
# </h3>

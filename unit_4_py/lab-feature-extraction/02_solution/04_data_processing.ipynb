# %% [markdown]
# ## 00 |

# %% [markdown]
# The objective of this **project** is to define the profile of the most profitable customers, based on a collection of **9.134** customer data, including demographics and buying behaviour.

# %%
# 📚 Basic libraries
import os # file managment
import pandas as pd # data manipulation
import numpy as np # numerical operations
import math # math in-build
import matplotlib.pyplot as plt # 2D visualization
import seaborn as sns # HD visualization
import warnings # warning messages managment

# 🤖 Machine Learning
from sklearn.preprocessing import StandardScaler # data normalization
from sklearn.model_selection import train_test_split # splitting data into train/test sets
from sklearn.linear_model import LinearRegression # logistic model
from sklearn.linear_model import ElasticNet, Lasso, Ridge # Regression model
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error # model evaluation metrics

# ⚙️ Settings
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore') # ignore warnings

# 🔄 Functions
import sys # system path to our functions
sys.path.append("C:/Users/apisi/01. IronData/01. GitHub/01. IronLabs/unit_4_py/lab-cleaning-numerical-data")

from easy.functions import open_data # quick data overview
from easy.functions import snake_columns # snake_case
from easy.functions import explore_data # checks for duplicates, NaN & empty spaces

# %%
file_path = os.path.join("C:/Users/apisi/01. IronData/01. GitHub/01. IronLabs/unit_4_py/lab-cleaning-numerical-data/01_data/X_N.csv")
X_N = pd.read_csv(file_path)

# %% [markdown]
# ## 04 | Data Processing

# %% [markdown]
# ### Normalizing the Data

# %%
# We don't want to normalize the target
num2 = X_N.drop(columns=['total_claim_amount'])

# Selecting the scaler
transformer = StandardScaler().fit(num2)

n = transformer.transform(num2)
n = pd.DataFrame(n) # making it a panda dataframe
n['total_claim_amount'] = X_N['total_claim_amount'] # adding our target
n.columns = X_N.columns # keeping old columns
n.sample(3)
# Out:
#       Unnamed: 0  response  coverage  education  policy_type    policy  \
# 4442   -0.047217 -0.408822 -0.732899  -1.187838    -0.551841 -0.120468
# 8864    1.629842 -0.408822  2.316897   0.666655     1.298568  1.562895
# 7247    1.016589 -0.408822  0.791999  -0.260591    -0.551841 -1.242711
#
#       vehicle_size  year     month       day  unnamed:_0  \
# 4442      2.027897   0.0  1.075304 -1.324482   -0.047217
# 8864      0.166682   0.0 -0.929969 -0.399979    1.629842
# 7247      0.166682   0.0  1.075304 -0.168853    1.016589
#
#       customer_lifetime_value    income  monthly_premium_auto  \
# 4442                -0.183346 -1.239617              2.871024
# 8864                -0.633397 -1.239617              0.400531
# 7247                 0.513571  0.113259              0.080820
#
#       months_since_last_claim  months_since_policy_inception  \
# 4442                -1.399525                      -0.754883
# 8864                 1.678099                      -0.181498
# 7247                -1.200968                      -1.184921
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 4442                   -0.42225           -0.822648         1921.248929
# 8864                   -0.42225           -0.822648          770.400000
# 7247                   -0.42225           -0.404247          250.058657

# %% [markdown]
# ### Visualizing the changes

# %%
fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(20, 16))
color = '#0072B2'  # blue

for i, ax in enumerate(axes.flat):
    if i >= len(n.columns):
        break
    sns.histplot(data=n, x=n.columns[i], color=color, bins=20, kde=True, ax=ax)
    ax.set_title(n.columns[i])
    ax.set_xlabel(n.columns[i])
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Merging get_dummies Categoricals with Numericals

# %%
file_path = os.path.join("C:/Users/apisi/01. IronData/01. GitHub/01. IronLabs/unit_4_py/lab-cleaning-numerical-data/01_data/c_dumm.csv")
c_dumm = pd.read_csv(file_path)

# %%
# Merging the two dataframes
X_N = pd.concat([c_dumm, n], axis=1)
X_N.sample(3)
# Out:
#       Unnamed: 0  state_Arizona  state_California  state_Nevada  state_Oregon  \
# 6694        6694              0                 0             1             0
# 1301        1301              0                 0             0             1
# 7302        7302              0                 1             0             0
#
#       state_Washington  employmentstatus_Disabled  employmentstatus_Employed  \
# 6694                 0                          0                          0
# 1301                 0                          0                          0
# 7302                 0                          0                          0
#
#       employmentstatus_Medical Leave  employmentstatus_Retired  \
# 6694                               0                         0
# 1301                               0                         0
# 7302                               0                         0
#
#       employmentstatus_Unemployed  gender_F  gender_M  location_code_Rural  \
# 6694                            1         1         0                    0
# 1301                            1         0         1                    0
# 7302                            1         1         0                    0
#
#       location_code_Suburban  location_code_Urban  marital_status_Divorced  \
# 6694                       1                    0                        0
# 1301                       1                    0                        0
# 7302                       0                    1                        0
#
#       marital_status_Married  marital_status_Single  renew_offer_type_Offer1  \
# 6694                       0                      1                        1
# 1301                       1                      0                        0
# 7302                       1                      0                        0
#
#       renew_offer_type_Offer2  renew_offer_type_Offer3  \
# 6694                        0                        0
# 1301                        1                        0
# 7302                        0                        0
#
#       renew_offer_type_Offer4  sales_channel_Agent  sales_channel_Branch  \
# 6694                        0                    0                     1
# 1301                        0                    1                     0
# 7302                        1                    0                     0
#
#       sales_channel_Call Center  sales_channel_Web  \
# 6694                          0                  0
# 1301                          0                  0
# 7302                          0                  1
#
#       vehicle_class_Four-Door Car  vehicle_class_Luxury Car  \
# 6694                            0                         0
# 1301                            0                         0
# 7302                            1                         0
#
#       vehicle_class_Luxury SUV  vehicle_class_SUV  vehicle_class_Sports Car  \
# 6694                         0                  1                         0
# 1301                         0                  0                         0
# 7302                         0                  0                         0
#
#       vehicle_class_Two-Door Car  Unnamed: 0  response  coverage  education  \
# 6694                           0    0.806862 -0.408822 -0.732899  -0.260591
# 1301                           1   -1.238452  2.446054 -0.732899  -0.260591
# 7302                           0    1.037448 -0.408822 -0.732899   0.666655
#
#       policy_type    policy  vehicle_size  year     month       day  \
# 6694    -0.551841 -1.242711      0.166682   0.0 -0.929969  1.795716
# 1301    -0.551841 -0.681590      0.166682   0.0 -0.929969 -1.440045
# 7302    -0.551841 -0.120468      0.166682   0.0 -0.929969  0.755650
#
#       unnamed:_0  customer_lifetime_value    income  monthly_premium_auto  \
# 6694    0.806862                 2.362784 -1.239617              0.458660
# 1301   -1.238452                 1.953063 -1.239617             -0.820183
# 7302    1.037448                -0.433180 -1.239617             -0.762054
#
#       months_since_last_claim  months_since_policy_inception  \
# 6694                 0.387483                       0.033522
# 1301                -0.605299                      -0.611536
# 7302                 0.586039                       0.427724
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 6694                   1.774747           -0.404247          784.800000
# 1301                  -0.422250           -0.404247          312.000000
# 7302                  -0.422250            0.850957          216.196521

# %% [markdown]
# ### X-Y Split

# %%
X_N.isnull().sum()
# Out:
# Unnamed: 0                        0
# state_Arizona                     0
# state_California                  0
# state_Nevada                      0
# state_Oregon                      0
# state_Washington                  0
# employmentstatus_Disabled         0
# employmentstatus_Employed         0
# employmentstatus_Medical Leave    0
# employmentstatus_Retired          0
# employmentstatus_Unemployed       0
# gender_F                          0
# gender_M                          0
# location_code_Rural               0
# location_code_Suburban            0
# location_code_Urban               0
# marital_status_Divorced           0
# marital_status_Married            0
# marital_status_Single             0
# renew_offer_type_Offer1           0
# renew_offer_type_Offer2           0
# renew_offer_type_Offer3           0
# renew_offer_type_Offer4           0
# sales_channel_Agent               0
# sales_channel_Branch              0
# sales_channel_Call Center         0
# sales_channel_Web                 0
# vehicle_class_Four-Door Car       0
# vehicle_class_Luxury Car          0
# vehicle_class_Luxury SUV          0
# vehicle_class_SUV                 0
# vehicle_class_Sports Car          0
# vehicle_class_Two-Door Car        0
# Unnamed: 0                        0
# response                          0
# coverage                          0
# education                         0
# policy_type                       0
# policy                            0
# vehicle_size                      0
# year                              0
# month                             0
# day                               0
# unnamed:_0                        0
# customer_lifetime_value           0
# income                            0
# monthly_premium_auto              0
# months_since_last_claim           0
# months_since_policy_inception     0
# number_of_open_complaints         0
# number_of_policies                0
# total_claim_amount                0
# dtype: int64

# %%
# We need to be careful about when and how we do the split.
X_N.dropna(inplace=True) # Droping nulls, we got an error when we tried to model
Y = X_N['total_claim_amount']
X = X_N.drop(['total_claim_amount'], axis=1)

# %% [markdown]
# ### Merging get_dummies Categoricals with Numericals

# %%
# Merging the two dataframes
X_N = pd.concat([c_dumm, n], axis=1)
X_N.sample(3)
# Out:
#       Unnamed: 0  state_Arizona  state_California  state_Nevada  state_Oregon  \
# 5348        5348              0                 0             0             1
# 8121        8121              0                 0             0             1
# 2531        2531              0                 0             0             1
#
#       state_Washington  employmentstatus_Disabled  employmentstatus_Employed  \
# 5348                 0                          0                          1
# 8121                 0                          0                          0
# 2531                 0                          0                          0
#
#       employmentstatus_Medical Leave  employmentstatus_Retired  \
# 5348                               0                         0
# 8121                               1                         0
# 2531                               0                         0
#
#       employmentstatus_Unemployed  gender_F  gender_M  location_code_Rural  \
# 5348                            0         0         1                    0
# 8121                            0         1         0                    0
# 2531                            1         0         1                    0
#
#       location_code_Suburban  location_code_Urban  marital_status_Divorced  \
# 5348                       1                    0                        0
# 8121                       1                    0                        0
# 2531                       1                    0                        0
#
#       marital_status_Married  marital_status_Single  renew_offer_type_Offer1  \
# 5348                       1                      0                        0
# 8121                       1                      0                        1
# 2531                       1                      0                        1
#
#       renew_offer_type_Offer2  renew_offer_type_Offer3  \
# 5348                        1                        0
# 8121                        0                        0
# 2531                        0                        0
#
#       renew_offer_type_Offer4  sales_channel_Agent  sales_channel_Branch  \
# 5348                        0                    0                     1
# 8121                        0                    0                     0
# 2531                        0                    0                     0
#
#       sales_channel_Call Center  sales_channel_Web  \
# 5348                          0                  0
# 8121                          1                  0
# 2531                          1                  0
#
#       vehicle_class_Four-Door Car  vehicle_class_Luxury Car  \
# 5348                            1                         0
# 8121                            1                         0
# 2531                            0                         0
#
#       vehicle_class_Luxury SUV  vehicle_class_SUV  vehicle_class_Sports Car  \
# 5348                         0                  0                         0
# 8121                         0                  0                         0
# 2531                         0                  0                         0
#
#       vehicle_class_Two-Door Car  Unnamed: 0  response  coverage  education  \
# 5348                           0    0.296387 -0.408822  0.791999   2.521148
# 8121                           0    1.348057 -0.408822  0.791999  -1.187838
# 2531                           1   -0.771971 -0.408822 -0.732899   0.666655
#
#       policy_type    policy  vehicle_size  year     month       day  \
# 5348    -0.551841 -0.681590      0.166682   0.0  1.075304  0.524524
# 8121     1.298568  1.001774     -1.694533   0.0  1.075304 -1.208919
# 2531    -0.551841 -0.120468      0.166682   0.0 -0.929969  0.524524
#
#       unnamed:_0  customer_lifetime_value    income  monthly_premium_auto  \
# 5348    0.296387                -0.192104  0.612696             -0.297020
# 8121    1.348057                -0.160247 -0.715525             -0.035438
# 2531   -0.771971                -0.758249 -1.239617             -0.558602
#
#       months_since_last_claim  months_since_policy_inception  \
# 5348                 0.784596                      -1.650797
# 8121                -0.605299                      -1.292431
# 2531                -0.903134                       0.463560
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 5348                  -0.422250            0.432555          398.400000
# 8121                   0.676249            0.432555          571.549745
# 2531                  -0.422250           -0.822648          420.765993

# %% [markdown]
# ### X-Y Split

# %%
X_N.isnull().sum()
# Out:
# Unnamed: 0                        0
# state_Arizona                     0
# state_California                  0
# state_Nevada                      0
# state_Oregon                      0
# state_Washington                  0
# employmentstatus_Disabled         0
# employmentstatus_Employed         0
# employmentstatus_Medical Leave    0
# employmentstatus_Retired          0
# employmentstatus_Unemployed       0
# gender_F                          0
# gender_M                          0
# location_code_Rural               0
# location_code_Suburban            0
# location_code_Urban               0
# marital_status_Divorced           0
# marital_status_Married            0
# marital_status_Single             0
# renew_offer_type_Offer1           0
# renew_offer_type_Offer2           0
# renew_offer_type_Offer3           0
# renew_offer_type_Offer4           0
# sales_channel_Agent               0
# sales_channel_Branch              0
# sales_channel_Call Center         0
# sales_channel_Web                 0
# vehicle_class_Four-Door Car       0
# vehicle_class_Luxury Car          0
# vehicle_class_Luxury SUV          0
# vehicle_class_SUV                 0
# vehicle_class_Sports Car          0
# vehicle_class_Two-Door Car        0
# Unnamed: 0                        0
# response                          0
# coverage                          0
# education                         0
# policy_type                       0
# policy                            0
# vehicle_size                      0
# year                              0
# month                             0
# day                               0
# unnamed:_0                        0
# customer_lifetime_value           0
# income                            0
# monthly_premium_auto              0
# months_since_last_claim           0
# months_since_policy_inception     0
# number_of_open_complaints         0
# number_of_policies                0
# total_claim_amount                0
# dtype: int64

# %%
# We need to be careful about when and how we do the split.
X_N.dropna(inplace=True) # Droping nulls, we got an error when we tried to model
Y = X_N['total_claim_amount']
X = X_N.drop(['total_claim_amount'], axis=1)
